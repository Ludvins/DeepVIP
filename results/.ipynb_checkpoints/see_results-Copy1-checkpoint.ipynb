# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as Circle

import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Load CSV and drop columns where all the values coincide. For example, the activation used.

# %%
df = pd.read_csv("dvip_sqrt.csv")
df = df.loc[:, (df != df.iloc[0]).any()]

# %% [markdown]
# Group table by their common parameters and compute mean and std over split

# %%
def std(x):
    return np.std(x)/np.sqrt(len(x))
vip = df.groupby(["dataset_name","vip_layers"]).agg(["mean", std])
vip
# Out:
#                              split            LOSS_train           RMSE_train  \
#                               mean       std        mean       std       mean
# dataset_name vip_layers
# boston       [1]          9.500000  1.289380   53.797053  3.072605   1.630169
#              [2]          9.500000  1.289380    7.567183  2.622715   1.200312
#              [3]          9.571429  1.809031    6.512097  4.763861   1.240816
# concrete     [1]          9.500000  1.289380  225.211185  5.126521   4.149940
#              [2]          9.736842  1.335312  176.226439  5.530697   3.011374
#              [3]          9.500000  1.289380  141.631710  4.073478   2.989387
# energy       [1]          9.500000  1.289380 -613.234680  8.694315   0.481015
#              [2]         10.230769  1.406468 -685.600267  8.522522   0.426853
#
#                                   NLL_train           CRPS_train            \
#                               std      mean       std       mean       std
# dataset_name vip_layers
# boston       [1]         0.013516  2.092650  0.006916   0.968747  0.006972
#              [2]         0.014705  1.830738  0.007450   0.740817  0.006761
#              [3]         0.014946  1.842478  0.008871   0.756726  0.007504
# concrete     [1]         0.030764  2.907127  0.006490   2.360862  0.017171
#              [2]         0.020615  2.670700  0.005561   1.763491  0.010183
#              [3]         0.023194  2.667591  0.005863   1.753547  0.011326
# energy       [1]         0.003935  1.188351  0.011597   0.355014  0.003703
#              [2]         0.003733  0.972947  0.010601   0.293760  0.002746
#
#                                 LOSS                  RMSE            \
#                                 mean         std      mean       std
# dataset_name vip_layers
# boston       [1]          593.204152   42.122035  3.753027  0.117254
#              [2]         1014.666296  128.726779  3.657867  0.230028
#              [3]         1134.906475  176.877615  3.858040  0.287095
# concrete     [1]          490.564938   29.213249  5.486224  0.121581
#              [2]          499.184374   32.955758  4.378608  0.119841
#              [3]          468.078622   40.672477  4.367459  0.139784
# energy       [1]         -584.378256    9.779080  0.540635  0.012693
#              [2]         -657.781180   14.462883  0.472435  0.016907
#
#                               NLL                CRPS
#                              mean       std      mean       std
# dataset_name vip_layers
# boston       [1]         2.911227  0.066143  1.971297  0.050562
#              [2]         3.102125  0.186389  1.733936  0.068930
#              [3]         3.081481  0.236022  1.795964  0.083732
# concrete     [1]         3.130498  0.023991  2.999731  0.051393
#              [2]         2.894970  0.020219  2.356954  0.047575
#              [3]         2.887822  0.023339  2.345088  0.052187
# energy       [1]         1.212390  0.011341  0.374756  0.004673
#              [2]         0.996441  0.015166  0.309690  0.006313

# %% [markdown]
# # Comparative with other models

# %%
vip100 = pd.read_csv("dvip.csv")
vip100 = vip100.loc[:, (vip100 != df.iloc[0]).any()] 
vip100 = vip100.groupby(["dataset_name","vip_layers", "epochs", "bnn_structure", "dropout", "zero_mean_prior", "fix_prior_noise", "prior_kl"]).agg(["mean", std])
vip100 = vip100.query("zero_mean_prior == False and epochs == 40000 and bnn_structure == '[100, 100]' and dropout == 0.1")
vip100
# Out:
#                                                                                               Unnamed: 0  \
#                                                                                                     mean
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False             0
# concrete     [1]        40000  [100, 100]    0.1     False           True            False             0
# energy       [1]        40000  [100, 100]    0.1     False           True            False             0
# naval        [1]        40000  [100, 100]    0.1     False           True            False             0
# power        [1]        40000  [100, 100]    0.1     False           True            False             0
# winered      [1]        40000  [100, 100]    0.1     False           True            False             0
#
#                                                                                                    \
#                                                                                               std
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False      0
# concrete     [1]        40000  [100, 100]    0.1     False           True            False      0
# energy       [1]        40000  [100, 100]    0.1     False           True            False      0
# naval        [1]        40000  [100, 100]    0.1     False           True            False      0
# power        [1]        40000  [100, 100]    0.1     False           True            False      0
# winered      [1]        40000  [100, 100]    0.1     False           True            False      0
#
#                                                                                               num_samples_train  \
#                                                                                                            mean
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False                    1
# concrete     [1]        40000  [100, 100]    0.1     False           True            False                    1
# energy       [1]        40000  [100, 100]    0.1     False           True            False                    1
# naval        [1]        40000  [100, 100]    0.1     False           True            False                    1
# power        [1]        40000  [100, 100]    0.1     False           True            False                    1
# winered      [1]        40000  [100, 100]    0.1     False           True            False                    1
#
#                                                                                                    \
#                                                                                               std
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False      0
# concrete     [1]        40000  [100, 100]    0.1     False           True            False      0
# energy       [1]        40000  [100, 100]    0.1     False           True            False      0
# naval        [1]        40000  [100, 100]    0.1     False           True            False      0
# power        [1]        40000  [100, 100]    0.1     False           True            False      0
# winered      [1]        40000  [100, 100]    0.1     False           True            False      0
#
#                                                                                               num_samples_test  \
#                                                                                                           mean
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False                 200
# concrete     [1]        40000  [100, 100]    0.1     False           True            False                 200
# energy       [1]        40000  [100, 100]    0.1     False           True            False                 200
# naval        [1]        40000  [100, 100]    0.1     False           True            False                 200
# power        [1]        40000  [100, 100]    0.1     False           True            False                 200
# winered      [1]        40000  [100, 100]    0.1     False           True            False                 200
#
#                                                                                                    \
#                                                                                               std
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False      0
# concrete     [1]        40000  [100, 100]    0.1     False           True            False      0
# energy       [1]        40000  [100, 100]    0.1     False           True            False      0
# naval        [1]        40000  [100, 100]    0.1     False           True            False      0
# power        [1]        40000  [100, 100]    0.1     False           True            False      0
# winered      [1]        40000  [100, 100]    0.1     False           True            False      0
#
#                                                                                               regression_coeffs  \
#                                                                                                            mean
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False                   20
# concrete     [1]        40000  [100, 100]    0.1     False           True            False                   20
# energy       [1]        40000  [100, 100]    0.1     False           True            False                   20
# naval        [1]        40000  [100, 100]    0.1     False           True            False                   20
# power        [1]        40000  [100, 100]    0.1     False           True            False                   20
# winered      [1]        40000  [100, 100]    0.1     False           True            False                   20
#
#                                                                                                    \
#                                                                                               std
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False      0
# concrete     [1]        40000  [100, 100]    0.1     False           True            False      0
# energy       [1]        40000  [100, 100]    0.1     False           True            False      0
# naval        [1]        40000  [100, 100]    0.1     False           True            False      0
# power        [1]        40000  [100, 100]    0.1     False           True            False      0
# winered      [1]        40000  [100, 100]    0.1     False           True            False      0
#
#                                                                                               batch_size  \
#                                                                                                     mean
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False         10000
# concrete     [1]        40000  [100, 100]    0.1     False           True            False         10000
# energy       [1]        40000  [100, 100]    0.1     False           True            False         10000
# naval        [1]        40000  [100, 100]    0.1     False           True            False         10000
# power        [1]        40000  [100, 100]    0.1     False           True            False         10000
# winered      [1]        40000  [100, 100]    0.1     False           True            False         10000
#
#                                                                                                    \
#                                                                                               std
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False      0
# concrete     [1]        40000  [100, 100]    0.1     False           True            False      0
# energy       [1]        40000  [100, 100]    0.1     False           True            False      0
# naval        [1]        40000  [100, 100]    0.1     False           True            False      0
# power        [1]        40000  [100, 100]    0.1     False           True            False      0
# winered      [1]        40000  [100, 100]    0.1     False           True            False      0
#
#                                                                                                ...  \
#                                                                                                ...
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl  ...
# boston       [1]        40000  [100, 100]    0.1     False           True            False     ...
# concrete     [1]        40000  [100, 100]    0.1     False           True            False     ...
# energy       [1]        40000  [100, 100]    0.1     False           True            False     ...
# naval        [1]        40000  [100, 100]    0.1     False           True            False     ...
# power        [1]        40000  [100, 100]    0.1     False           True            False     ...
# winered      [1]        40000  [100, 100]    0.1     False           True            False     ...
#
#                                                                                               CRPS_train  \
#                                                                                                     mean
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False      0.285299
# concrete     [1]        40000  [100, 100]    0.1     False           True            False      0.840855
# energy       [1]        40000  [100, 100]    0.1     False           True            False      0.134532
# naval        [1]        40000  [100, 100]    0.1     False           True            False      0.000371
# power        [1]        40000  [100, 100]    0.1     False           True            False      1.755334
# winered      [1]        40000  [100, 100]    0.1     False           True            False      0.078045
#
#                                                                                                              \
#                                                                                                         std
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False     1.425383e-03
# concrete     [1]        40000  [100, 100]    0.1     False           True            False     7.972744e-03
# energy       [1]        40000  [100, 100]    0.1     False           True            False     4.162599e-04
# naval        [1]        40000  [100, 100]    0.1     False           True            False     6.102968e-07
# power        [1]        40000  [100, 100]    0.1     False           True            False     3.978214e-03
# winered      [1]        40000  [100, 100]    0.1     False           True            False     1.707176e-04
#
#                                                                                                        LOSS  \
#                                                                                                        mean
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False      3685.116028
# concrete     [1]        40000  [100, 100]    0.1     False           True            False       837.572041
# energy       [1]        40000  [100, 100]    0.1     False           True            False      -813.152246
# naval        [1]        40000  [100, 100]    0.1     False           True            False    -12799.758398
# power        [1]        40000  [100, 100]    0.1     False           True            False      -590.885061
# winered      [1]        40000  [100, 100]    0.1     False           True            False      5387.365955
#
#                                                                                                            \
#                                                                                                       std
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False     493.835913
# concrete     [1]        40000  [100, 100]    0.1     False           True            False     153.898680
# energy       [1]        40000  [100, 100]    0.1     False           True            False      25.989766
# naval        [1]        40000  [100, 100]    0.1     False           True            False       7.512435
# power        [1]        40000  [100, 100]    0.1     False           True            False     174.101466
# winered      [1]        40000  [100, 100]    0.1     False           True            False     171.410034
#
#                                                                                                    RMSE  \
#                                                                                                    mean
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False     3.348571
# concrete     [1]        40000  [100, 100]    0.1     False           True            False     3.877127
# energy       [1]        40000  [100, 100]    0.1     False           True            False     0.414635
# naval        [1]        40000  [100, 100]    0.1     False           True            False     0.000352
# power        [1]        40000  [100, 100]    0.1     False           True            False     3.584339
# winered      [1]        40000  [100, 100]    0.1     False           True            False     0.578020
#
#                                                                                                          \
#                                                                                                     std
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False     0.171408
# concrete     [1]        40000  [100, 100]    0.1     False           True            False     0.130888
# energy       [1]        40000  [100, 100]    0.1     False           True            False     0.012840
# naval        [1]        40000  [100, 100]    0.1     False           True            False     0.000007
# power        [1]        40000  [100, 100]    0.1     False           True            False     0.065615
# winered      [1]        40000  [100, 100]    0.1     False           True            False     0.008863
#
#                                                                                                     NLL  \
#                                                                                                    mean
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False     6.736981
# concrete     [1]        40000  [100, 100]    0.1     False           True            False     3.025553
# energy       [1]        40000  [100, 100]    0.1     False           True            False     0.594359
# naval        [1]        40000  [100, 100]    0.1     False           True            False    -5.579109
# power        [1]        40000  [100, 100]    0.1     False           True            False     2.698216
# winered      [1]        40000  [100, 100]    0.1     False           True            False     1.836591
#
#                                                                                                          \
#                                                                                                     std
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False     0.871211
# concrete     [1]        40000  [100, 100]    0.1     False           True            False     0.109934
# energy       [1]        40000  [100, 100]    0.1     False           True            False     0.020212
# naval        [1]        40000  [100, 100]    0.1     False           True            False     0.002378
# power        [1]        40000  [100, 100]    0.1     False           True            False     0.017949
# winered      [1]        40000  [100, 100]    0.1     False           True            False     0.078158
#
#                                                                                                    CRPS  \
#                                                                                                    mean
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False     1.761263
# concrete     [1]        40000  [100, 100]    0.1     False           True            False     1.949076
# energy       [1]        40000  [100, 100]    0.1     False           True            False     0.230616
# naval        [1]        40000  [100, 100]    0.1     False           True            False     0.000375
# power        [1]        40000  [100, 100]    0.1     False           True            False     1.939639
# winered      [1]        40000  [100, 100]    0.1     False           True            False     0.313622
#
#
#                                                                                                         std
# dataset_name vip_layers epochs bnn_structure dropout zero_mean_prior fix_prior_noise prior_kl
# boston       [1]        40000  [100, 100]    0.1     False           True            False     5.635845e-02
# concrete     [1]        40000  [100, 100]    0.1     False           True            False     4.966855e-02
# energy       [1]        40000  [100, 100]    0.1     False           True            False     5.264395e-03
# naval        [1]        40000  [100, 100]    0.1     False           True            False     4.283174e-07
# power        [1]        40000  [100, 100]    0.1     False           True            False     1.178979e-02
# winered      [1]        40000  [100, 100]    0.1     False           True            False     4.819761e-03
#
# [6 rows x 42 columns]

# %%
doubly = pd.read_csv("doubly.csv")
doubly = doubly.groupby(["dataset", "layers"]).agg(["mean", std]).drop("split", axis = 1)
doubly
# Out:
#                       NLL                RMSE                CRPS
#                      mean       std      mean       std      mean       std
# dataset  layers
# boston   1       2.621324  0.061539  3.461930  0.172243  1.778254  0.054756
#          2       2.619427  0.060715  3.464310  0.174090  1.775397  0.055053
#          3       2.618580  0.057986  3.477714  0.176407  1.780114  0.056023
#          4       2.612612  0.056778  3.459250  0.180476  1.768086  0.057338
#          5       2.619665  0.058376  3.483772  0.184585  1.778915  0.059403
# concrete 1       3.134538  0.016871  5.699006  0.128251  3.104325  0.057626
#          2       3.137992  0.016458  5.709117  0.127669  3.113382  0.057095
#          3       3.142599  0.016832  5.724927  0.129163  3.125693  0.058891
#          4       3.134859  0.017792  5.658314  0.130668  3.083788  0.057433
#          5       3.092611  0.015842  5.374571  0.115534  2.942421  0.051177
# energy   1       1.141213  0.016797  0.713296  0.020260  0.414601  0.009610
#          2       0.661802  0.019321  0.451084  0.012712  0.252025  0.005593
#          3       0.711009  0.021007  0.462688  0.013160  0.262231  0.005888
#          4       0.759983  0.021207  0.478973  0.014059  0.273281  0.006523
#          5       0.700959  0.021684  0.458096  0.015404  0.259230  0.007059
# kin8nm   1      -0.975375  0.003277  0.086898  0.000536  0.049229  0.000258
#          2      -1.350378  0.004308  0.062584  0.000347  0.035030  0.000162
#          3      -1.382660  0.006671  0.060735  0.000458  0.033985  0.000235
# naval    1      -6.475724  0.117892  0.000285  0.000035  0.000185  0.000020
#          2      -6.894672  0.101289  0.000152  0.000036  0.000119  0.000017
#          3      -7.039468  0.049660  0.000085  0.000012  0.000091  0.000006
#          4      -6.959729  0.055067  0.000109  0.000016  0.000102  0.000007
#          5      -6.873125  0.072354  0.000159  0.000025  0.000120  0.000010
# power    1       2.806324  0.009995  3.993163  0.040720  2.173505  0.011311
#          2       2.770222  0.009873  3.850422  0.038183  2.075122  0.009159
#          3       2.747370  0.012654  3.760601  0.049078  2.023911  0.015586
#          4       2.732378  0.011725  3.702821  0.045233  1.984471  0.012649
#          5       2.735273  0.010918  3.712386  0.041823  1.991525  0.009105
# protein  1       2.907479  0.002265  4.428554  0.011083  2.481267  0.005884
#          2       2.786240  0.002311  3.936413  0.010322  2.161253  0.004967
#          3       2.715014  0.002847  3.708458  0.011970  2.002001  0.005932
#          4       2.689973  0.002877  3.641484  0.011498  1.950791  0.005703
#          5       2.692614  0.004289  3.663181  0.016545  1.957200  0.008180
# wine_red 1       0.928739  0.012829  0.614669  0.008504  0.340628  0.004178
#          2       0.928976  0.012711  0.614753  0.008461  0.340674  0.004151
#          3       0.929331  0.012509  0.615001  0.008325  0.340852  0.004091
#          4       0.929474  0.012561  0.614968  0.008397  0.340988  0.004120
#          5       0.929893  0.012395  0.615139  0.008317  0.341113  0.004076

# %%
def comparative_plot(model_names, mean_values, std_values, colors, ax):
    """
    Creates a plot where the different models are shown in the "y" axis and mean and std values on the x axis.
    The first model is used to create a vertical dashed line, as a benchmark.
    """
    # Compute mean and std of points 
    mean = np.nanmean(mean_values)
    std = np.nanstd(mean_values)
    # Replace non-existint results (np.nan) with a white point (invisible).
    nan_pos = np.isnan(mean_values)
    c = np.array(colors)
    c[nan_pos] = "white"
    means = np.array(mean_values)
    means[nan_pos] = mean
    
    # Compute points that are far from the mean and meake them invisible
    far = means - mean > 2*std
    means[far] = mean
    c[far] = "white"
    
    # Scatter points
    ax.scatter(means, model_names, c = c, plotnonfinite = True)
    # Draw std horizontal lines
    ax.hlines(np.array(model_names)[~far], np.array(mean_values - std_values)[~far],np.array(means + std_values)[~far], colors= np.array(colors)[~far])
    # Draw baseline line on first model
    ax.axvline(mean_values[0], linestyle = "dashed", color = "k")
    
    # Plot an arrow for far points.
    if far.any() != 0:
        x_min, x_max = ax.get_xlim()
        slope = (x_max - x_min)/5
        ax.arrow(x = x_max - slope, y = np.array(model_names)[far][0], 
                 dx = slope, dy =0, color = np.array(colors)[far][0],
                 width = 0.002, head_width=0.3, head_length=slope/3, linewidth=1, length_includes_head = True,
                )
        
def get_dataset(dataset, metric, agg, train_metrics = False):
    if dataset == "winered":
        d_dataset = "wine_red"
    else:
        d_dataset = dataset
    vip_query = vip.query("dataset_name == @dataset").xs((metric + "_train" if train_metrics else metric, agg),axis=1).to_frame()
    vip100_query = vip100.query("dataset_name == @dataset").xs((metric, agg),axis=1).to_frame()
    doubly_query = doubly.query("dataset == @d_dataset").xs((metric, agg),axis=1).to_frame()
    
    def item(array):
        if array.size == 0:
            return np.nan
        else:
            return array.item()
    
    ret = {"VIP": item(vip_query.query("vip_layers == '[1]'").to_numpy()),
          "DVIP 2": item(vip_query.query("vip_layers == '[2]'").to_numpy()),
          "DVIP 3": item(vip_query.query("vip_layers == '[3]'").to_numpy()),
          "DVIP 4": item(vip_query.query("vip_layers == '[4]'").to_numpy()),
          "DVIP 5": item(vip_query.query("vip_layers == '[5]'").to_numpy()),
          "VIP 100": item(vip100_query.query("vip_layers == '[1]'").to_numpy()),
          "DGP": item(doubly_query.query("layers == 1").to_numpy()),
          "DGP 2": item(doubly_query.query("layers == 2").to_numpy()),
          "DGP 3": item(doubly_query.query("layers == 3").to_numpy()) or np.nan,
          "DGP 4": item(doubly_query.query("layers == 4").to_numpy()) or np.nan,
          "DGP 5": item(doubly_query.query("layers == 5").to_numpy()) or np.nan
    }
    
    return ret

def plot_datasets(dataset_names, model_names, colors, metric, train_metrics = False):
    fig, ax = plt.subplots((len(dataset_names) - 1)//4 + 1, min(len(dataset_names), 4), figsize = (20, 10))
    fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

    for i in range(len(dataset_names)):
        dataset = dataset_names[i]
        if len(dataset_names) < 4:
            axis = ax[i]
        else:
            axis = ax[i// (len(dataset_names)//2), i%(len(dataset_names)//2)]
        axis.set_title(dataset.capitalize())
        axis.locator_params(axis="x", nbins=4)
        if i % 4 > 0:
            axis.tick_params(left = False)
            axis.set_yticklabels([])
        if i % 4 == min(len(dataset_names), 4) - 1:
            axis.yaxis.tick_right()
            axis.set_yticklabels(model_names)
        
        
        comparative_plot(model_names, 
                         np.array([get_dataset(dataset, metric, "mean", train_metrics).get(model, np.nan) for model in model_names]), 
                         np.array([get_dataset(dataset, metric, "std", train_metrics).get(model, np.nan) for model in model_names]), 
                         [colors[model] for model in model_names], 
                         axis)
        
    handles = [
        Circle.Patch(color='darkblue', label='Single layer models'),
        Circle.Patch(color='teal', label='This work'),
        Circle.Patch(color='darkorange', label='Deep GP models'),
        Circle.Patch(color='orchid', label='Bayesian NN'),
    ]

    if len(dataset_names) < 4:
        ax[len(dataset_names) - 1].legend(loc='upper center', bbox_to_anchor=(-0.6, -0.05),
              fancybox=True, shadow=True, ncol=5, handles = handles)
    else:
        ax[1][1].legend(loc='upper center', bbox_to_anchor=(1.1, -0.15),
              fancybox=True, shadow=True, ncol=5, handles = handles)

# %%
dataset_names = ["boston", "energy", "concrete", "winered", "power", "naval", "protein", "kin8nm"]
model_names = ["VIP", "DVIP 2", "DVIP 3", "DVIP 4", "DVIP 5", "VIP 100", "DGP", "DGP 2", "DGP 3", "DGP 4", "DGP 5"]
colors = {"VIP": "darkblue", 
          "DVIP 2": "teal", 
          "DVIP 3": "teal", 
          "DVIP 4": "teal", 
          "DVIP 5": "teal", 
          "VIP 100": "darkblue", 
          "DGP": "darkblue",
          "DGP 2": "darkorange", 
          "DGP 3": "darkorange",
          "DGP 4": "darkorange",
          "DGP 5": "darkorange"}

# %%
plot_datasets(dataset_names, model_names, colors, "RMSE")

# %%
plot_datasets(dataset_names, model_names, colors, "RMSE", train_metrics = True)

# %%
plot_datasets(dataset_names, model_names, colors, "NLL")

# %%
plot_datasets(dataset_names, model_names, colors, "NLL", train_metrics = True)

# %%
plot_datasets(dataset_names, model_names, colors, "CRPS")

# %%
plot_datasets(dataset_names, model_names, colors, "CRPS", train_metrics = True)
