# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as Circle

import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Load CSV and drop columns where all the values coincide. For example, the activation used.

# %%
df = pd.read_csv("dvip.csv")
df = df.loc[:, (df != df.iloc[0]).any()]

# %% [markdown]
# Group table by their common parameters and compute mean and std over split

# %%
def std(x):
    return np.std(x)/np.sqrt(len(x))
full_df = df.groupby(["dataset_name", "bnn_structure", "epochs", "dropout", "zero_mean_prior", "vip_layers", ]).agg(["mean", std])
full_df
# Out:
#                                                                          split  \
#                                                                           mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10, 10]      20000  0.1     False           [1]         9.500000
#                                                           [2]         9.500000
#                                                           [3]         9.500000
#                                                           [4]         9.500000
#                                                           [5]         9.500000
# ...                                                                        ...
# winered      [10]          40000  0.1     False           [2]         9.500000
#                                                           [3]         9.500000
#                                                           [4]         9.500000
#                                                           [5]         9.500000
#              [200, 200]    40000  0.1     False           [1]         7.666667
#
#                                                                                 \
#                                                                            std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10, 10]      20000  0.1     False           [1]         1.289380
#                                                           [2]         1.289380
#                                                           [3]         1.289380
#                                                           [4]         1.289380
#                                                           [5]         1.289380
# ...                                                                        ...
# winered      [10]          40000  0.1     False           [2]         1.289380
#                                                           [3]         1.289380
#                                                           [4]         1.289380
#                                                           [5]         1.289380
#              [200, 200]    40000  0.1     False           [1]         1.365921
#
#                                                                        LOSS_train  \
#                                                                              mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10, 10]      20000  0.1     False           [1]          110.412336
#                                                           [2]          137.308258
#                                                           [3]          166.658802
#                                                           [4]          203.286924
#                                                           [5]          252.520004
# ...                                                                           ...
# winered      [10]          40000  0.1     False           [2]         1477.869684
#                                                           [3]         1498.940063
#                                                           [4]         1527.434656
#                                                           [5]         1565.611090
#              [200, 200]    40000  0.1     False           [1]         -369.885040
#
#                                                                                 \
#                                                                            std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10, 10]      20000  0.1     False           [1]         2.683153
#                                                           [2]         2.538433
#                                                           [3]         2.404505
#                                                           [4]         3.027346
#                                                           [5]         3.792334
# ...                                                                        ...
# winered      [10]          40000  0.1     False           [2]         4.300125
#                                                           [3]         5.811296
#                                                           [4]         3.541869
#                                                           [5]         3.521059
#              [200, 200]    40000  0.1     False           [1]         3.068268
#
#                                                                      RMSE_train  \
#                                                                            mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10, 10]      20000  0.1     False           [1]          1.718580
#                                                           [2]          1.710933
#                                                           [3]          1.983479
#                                                           [4]          2.265911
#                                                           [5]          2.590312
# ...                                                                         ...
# winered      [10]          40000  0.1     False           [2]          0.441884
#                                                           [3]          0.475937
#                                                           [4]          0.504037
#                                                           [5]          0.527948
#              [200, 200]    40000  0.1     False           [1]          0.046470
#
#                                                                                 \
#                                                                            std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10, 10]      20000  0.1     False           [1]         0.011289
#                                                           [2]         0.010802
#                                                           [3]         0.016662
#                                                           [4]         0.023683
#                                                           [5]         0.031077
# ...                                                                        ...
# winered      [10]          40000  0.1     False           [2]         0.002335
#                                                           [3]         0.003096
#                                                           [4]         0.002931
#                                                           [5]         0.002266
#              [200, 200]    40000  0.1     False           [1]         0.000558
#
#                                                                      NLL_train  \
#                                                                           mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10, 10]      20000  0.1     False           [1]         2.210671
#                                                           [2]         2.173039
#                                                           [3]         2.282110
#                                                           [4]         2.390166
#                                                           [5]         2.510045
# ...                                                                        ...
# winered      [10]          40000  0.1     False           [2]         0.638522
#                                                           [3]         0.699697
#                                                           [4]         0.752034
#                                                           [5]         0.795692
#              [200, 200]    40000  0.1     False           [1]        -0.670645
#
#                                                                                 \
#                                                                            std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10, 10]      20000  0.1     False           [1]         0.006175
#                                                           [2]         0.005000
#                                                           [3]         0.006134
#                                                           [4]         0.007515
#                                                           [5]         0.008710
# ...                                                                        ...
# winered      [10]          40000  0.1     False           [2]         0.004702
#                                                           [3]         0.005799
#                                                           [4]         0.005442
#                                                           [5]         0.004043
#              [200, 200]    40000  0.1     False           [1]         0.002786
#
#                                                                      CRPS_train  \
#                                                                            mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10, 10]      20000  0.1     False           [1
# %% [markdown]
# # Existing configurations

# %%
df.groupby(["bnn_structure", "epochs", "dropout", "zero_mean_prior"]).mean().index
# Out:
# MultiIndex([(  '[10, 10]', 20000, 0.1, False),
#             (  '[10, 10]', 30000, 0.1, False),
#             (  '[10, 10]', 30000, 0.1,  True),
#             (  '[10, 10]', 40000, 0.1,  True),
#             ('[100, 100]', 40000, 0.1, False),
#             (      '[10]', 20000, 0.1, False),
#             (      '[10]', 30000, 0.1, False),
#             (      '[10]', 30000, 0.1,  True),
#             (      '[10]', 30000, 0.2, False),
#             (      '[10]', 40000, 0.1, False),
#             ('[200, 200]', 40000, 0.1, False)],
#            names=['bnn_structure', 'epochs', 'dropout', 'zero_mean_prior'])

# %% [markdown]
# # Comparative with other models

# %%
vip100 =  full_df.query("zero_mean_prior == False and epochs == 40000 and bnn_structure == '[100, 100]' and dropout == 0.1")
vip100
# Out:
#                                                                          split  \
#                                                                           mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         9.500000
# concrete     [100, 100]    40000  0.1     False           [1]         9.500000
# energy       [100, 100]    40000  0.1     False           [1]         9.500000
# naval        [100, 100]    40000  0.1     False           [1]         8.400000
# power        [100, 100]    40000  0.1     False           [1]         6.666667
# winered      [100, 100]    40000  0.1     False           [1]         9.500000
#
#                                                                                 \
#                                                                            std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         1.289380
# concrete     [100, 100]    40000  0.1     False           [1]         1.289380
# energy       [100, 100]    40000  0.1     False           [1]         1.289380
# naval        [100, 100]    40000  0.1     False           [1]         3.447898
# power        [100, 100]    40000  0.1     False           [1]         0.981307
# winered      [100, 100]    40000  0.1     False           [1]         1.289380
#
#                                                                         LOSS_train  \
#                                                                               mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]          -403.090915
# concrete     [100, 100]    40000  0.1     False           [1]          -523.686046
# energy       [100, 100]    40000  0.1     False           [1]         -1189.965643
# naval        [100, 100]    40000  0.1     False           [1]        -12866.564062
# power        [100, 100]    40000  0.1     False           [1]         -1419.721029
# winered      [100, 100]    40000  0.1     False           [1]           187.243884
#
#                                                                                  \
#                                                                             std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]          2.266139
# concrete     [100, 100]    40000  0.1     False           [1]          8.572548
# energy       [100, 100]    40000  0.1     False           [1]          1.751701
# naval        [100, 100]    40000  0.1     False           [1]         17.624524
# power        [100, 100]    40000  0.1     False           [1]         20.784891
# winered      [100, 100]    40000  0.1     False           [1]          2.268114
#
#                                                                      RMSE_train  \
#                                                                            mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]          0.267696
# concrete     [100, 100]    40000  0.1     False           [1]          1.458049
# energy       [100, 100]    40000  0.1     False           [1]          0.117665
# naval        [100, 100]    40000  0.1     False           [1]          0.000334
# power        [100, 100]    40000  0.1     False           [1]          3.249027
# winered      [100, 100]    40000  0.1     False           [1]          0.090865
#
#                                                                                 \
#                                                                            std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         0.003312
# concrete     [100, 100]    40000  0.1     False           [1]         0.028968
# energy       [100, 100]    40000  0.1     False           [1]         0.001290
# naval        [100, 100]    40000  0.1     False           [1]         0.000004
# power        [100, 100]    40000  0.1     False           [1]         0.009481
# winered      [100, 100]    40000  0.1     False           [1]         0.000343
#
#                                                                      NLL_train  \
#                                                                           mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         1.058159
# concrete     [100, 100]    40000  0.1     False           [1]         2.055470
# energy       [100, 100]    40000  0.1     False           [1]         0.311845
# naval        [100, 100]    40000  0.1     False           [1]        -5.582504
# power        [100, 100]    40000  0.1     False           [1]         2.612527
# winered      [100, 100]    40000  0.1     False           [1]        -0.278957
#
#                                                                                 \
#                                                                            std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         0.004506
# concrete     [100, 100]    40000  0.1     False           [1]         0.010434
# energy       [100, 100]    40000  0.1     False           [1]         0.002434
# naval        [100, 100]    40000  0.1     False           [1]         0.002659
# power        [100, 100]    40000  0.1     False           [1]         0.002800
# winered      [100, 100]    40000  0.1     False           [1]         0.001909
#
#                                                                      CRPS_train  \
#                                                                            mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]          0.285299
# concrete     [100, 100]    40000  0.1     False           [1]          0.840855
# energy       [100, 100]    40000  0.1     False           [1]          0.134532
# naval        [100, 100]    40000  0.1     False           [1]          0.000371
# power        [100, 100]    40000  0.1     False           [1]          1.755334
# winered      [100, 100]    40000  0.1     False           [1]          0.078045
#
#                                                                                     \
#                                                                                std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         1.425383e-03
# concrete     [100, 100]    40000  0.1     False           [1]         7.972744e-03
# energy       [100, 100]    40000  0.1     False           [1]         4.162599e-04
# naval        [100, 100]    40000  0.1     False           [1]         6.102968e-07
# power        [100, 100]    40000  0.1     False           [1]         3.978214e-03
# winered      [100, 100]    40000  0.1     False           [1]         1.707176e-04
#
#                                                                               LOSS  \
#                                                                               mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]          3685.116028
# concrete     [100, 100]    40000  0.1     False           [1]           837.572041
# energy       [100, 100]    40000  0.1     False           [1]          -813.152246
# naval        [100, 100]    40000  0.1     False           [1]        -12799.758398
# power        [100, 100]    40000  0.1     False           [1]          -590.885061
# winered      [100, 100]    40000  0.1     False           [1]          5387.365955
#
#                                                                                   \
#                                                                              std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         493.835913
# concrete     [100, 100]    40000  0.1     False           [1]         153.898680
# energy       [100, 100]    40000  0.1     False           [1]          25.989766
# naval        [100, 100]    40000  0.1     False           [1]           7.512435
# power        [100, 100]    40000  0.1     False           [1]         174.101466
# winered      [100, 100]    40000  0.1     False           [1]         171.410034
#
#                                                                           RMSE  \
#                                                                           mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         3.348571
# concrete     [100, 100]    40000  0.1     False           [1]         3.877127
# energy       [100, 100]    40000  0.1     False           [1]         0.414635
# naval        [100, 100]    40000  0.1     False           [1]         0.000352
# power        [100, 100]    40000  0.1     False           [1]         3.584339
# winered      [100, 100]    40000  0.1     False           [1]         0.578020
#
#                                                                                 \
#                                                                            std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         0.171408
# concrete     [100, 100]    40000  0.1     False           [1]         0.130888
# energy       [100, 100]    40000  0.1     False           [1]         0.012840
# naval        [100, 100]    40000  0.1     False           [1]         0.000007
# power        [100, 100]    40000  0.1     False           [1]         0.065615
# winered      [100, 100]    40000  0.1     False           [1]         0.008863
#
#                                                                            NLL  \
#                                                                           mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         6.736981
# concrete     [100, 100]    40000  0.1     False           [1]         3.025553
# energy       [100, 100]    40000  0.1     False           [1]         0.594359
# naval        [100, 100]    40000  0.1     False           [1]        -5.579109
# power        [100, 100]    40000  0.1     False           [1]         2.698216
# winered      [100, 100]    40000  0.1     False           [1]         1.836591
#
#                                                                                 \
#                                                                            std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         0.871211
# concrete     [100, 100]    40000  0.1     False           [1]         0.109934
# energy       [100, 100]    40000  0.1     False           [1]         0.020212
# naval        [100, 100]    40000  0.1     False           [1]         0.002378
# power        [100, 100]    40000  0.1     False           [1]         0.017949
# winered      [100, 100]    40000  0.1     False           [1]         0.078158
#
#                                                                           CRPS  \
#                                                                           mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         1.761263
# concrete     [100, 100]    40000  0.1     False           [1]         1.949076
# energy       [100, 100]    40000  0.1     False           [1]         0.230616
# naval        [100, 100]    40000  0.1     False           [1]         0.000375
# power        [100, 100]    40000  0.1     False           [1]         1.939639
# winered      [100, 100]    40000  0.1     False           [1]         0.313622
#
#
#                                                                                std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [100, 100]    40000  0.1     False           [1]         5.635845e-02
# concrete     [100, 100]    40000  0.1     False           [1]         4.966855e-02
# energy       [100, 100]    40000  0.1     False           [1]         5.264395e-03
# naval        [100, 100]    40000  0.1     False           [1]         4.283174e-07
# power        [100, 100]    40000  0.1     False           [1]         1.178979e-02
# winered      [100, 100]    40000  0.1     False           [1]         4.819761e-03

# %%
vip =  full_df.query("zero_mean_prior == False and epochs == 40000 and bnn_structure == '[10]' and dropout == 0.1")
vip
# Out:
#                                                                           split  \
#                                                                            mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10]          40000  0.1     False           [1]          9.500000
#                                                           [2]          9.500000
#                                                           [3]          9.500000
#                                                           [4]          9.500000
#                                                           [5]          9.500000
# concrete     [10]          40000  0.1     False           [1]          9.500000
#                                                           [2]          9.500000
#                                                           [3]          9.500000
#                                                           [4]          9.500000
#                                                           [5]          9.500000
# energy       [10]          40000  0.1     False           [1]          9.500000
#                                                           [2]          9.500000
#                                                           [3]          9.500000
#                                                           [4]          9.500000
#                                                           [5]          9.500000
# naval        [10]          40000  0.1     False           [1]          9.500000
#                                                           [2]          9.333333
#                                                           [3]          9.000000
#                                                           [4]         10.250000
#                                                           [5]         10.400000
# power        [10]          40000  0.1     False           [1]          9.157895
#                                                           [2]          9.500000
#                                                           [3]          9.500000
#                                                           [4]          9.500000
#                                                           [5]          9.473684
# protein      [10]          40000  0.1     False           [1]          9.500000
#                                                           [2]          9.500000
#                                                           [3]          8.000000
#                                                           [4]          6.000000
# winered      [10]          40000  0.1     False           [1]          9.500000
#                                                           [2]          9.500000
#                                                           [3]          9.500000
#                                                           [4]          9.500000
#                                                           [5]          9.500000
#
#                                                                                 \
#                                                                            std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10]          40000  0.1     False           [1]         1.289380
#                                                           [2]         1.289380
#                                                           [3]         1.289380
#                                                           [4]         1.289380
#                                                           [5]         1.289380
# concrete     [10]          40000  0.1     False           [1]         1.289380
#                                                           [2]         1.289380
#                                                           [3]         1.289380
#                                                           [4]         1.289380
#                                                           [5]         1.289380
# energy       [10]          40000  0.1     False           [1]         1.289380
#                                                           [2]         1.289380
#                                                           [3]         1.289380
#                                                           [4]         1.289380
#                                                           [5]         1.289380
# naval        [10]          40000  0.1     False           [1]         1.289380
#                                                           [2]         1.672434
#                                                           [3]         2.398979
#                                                           [4]         1.366451
#                                                           [5]         2.920274
# power        [10]          40000  0.1     False           [1]         1.311072
#                                                           [2]         1.289380
#                                                           [3]         1.289380
#                                                           [4]         1.289380
#                                                           [5]         1.356973
# protein      [10]          40000  0.1     False           [1]         1.289380
#                                                           [2]         1.289380
#                                                           [3]         1.660541
#                                                           [4]         2.031010
# winered      [10]          40000  0.1     False           [1]         1.289380
#                                                           [2]         1.289380
#                                                           [3]         1.289380
#                                                           [4]         1.289380
#                                                           [5]         1.289380
#
#                                                                         LOSS_train  \
#                                                                               mean
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10]          40000  0.1     False           [1
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10]          40000  0.1     False           [1]         1.971254
#                                                           [2]         1.750940
#                                                           [3]         1.817736
#                                                           [4]         1.760835
#                                                           [5]         1.781601
# concrete     [10]          40000  0.1     False           [1]         2.999735
#                                                           [2]         2.393940
#                                                           [3]         2.719083
#                                                           [4]         2.679982
#                                                           [5]         2.655145
# energy       [10]          40000  0.1     False           [1]         0.374756
#                                                           [2]         0.323819
#                                                           [3]         0.320698
#                                                           [4]         0.316440
#                                                           [5]         0.321526
# naval        [10]          40000  0.1     False           [1]         0.000720
#                                                           [2]         0.000668
#                                                           [3]         0.000647
#                                                           [4]         0.000618
#                                                           [5]         0.000669
# power        [10]          40000  0.1     False           [1]         2.188856
#                                                           [2]         2.109415
#                                                           [3]         2.111937
#                                                           [4]         2.109689
#                                                           [5]         2.107601
# protein      [10]          40000  0.1     False           [1]         2.534596
#                                                           [2]         2.315400
#                                                           [3]         2.254045
#                                                           [4]         2.223782
# winered      [10]          40000  0.1     False           [1]         0.353405
#                                                           [2]         0.338273
#                                                           [3]         0.339683
#                                                           [4]         0.345049
#                                                           [5]         0.345873
#
#
#                                                                            std
# dataset_name bnn_structure epochs dropout zero_mean_prior vip_layers
# boston       [10]          40000  0.1     False           [1]         0.050567
#                                                           [2]         0.084163
#                                                           [3]         0.091140
#                                                           [4]         0.091951
#                                                           [5]         0.088049
# concrete     [10]          40000  0.1     False           [1]         0.051393
#                                                           [2]         0.047277
#                                                           [3]         0.067886
#                                                           [4]         0.056596
#                                                           [5]         0.057559
# energy       [10]          40000  0.1     False           [1]         0.004673
#                                                           [2]         0.004789
#                                                           [3]         0.005373
#                                                           [4]         0.003926
#                                                           [5]         0.004676
# naval        [10]          40000  0.1     False           [1]         0.000010
#                                                           [2]         0.000008
#                                                           [3]         0.000006
#                                                           [4]         0.000014
#                                                           [5]         0.000010
# power        [10]          40000  0.1     False           [1]         0.012200
#                                                           [2]         0.009873
#                                                           [3]         0.010007
#                                                           [4]         0.010574
#                                                           [5]         0.011601
# protein      [10]          40000  0.1     False           [1]         0.007449
#                                                           [2]         0.007053
#                                                           [3]         0.006377
#                                                           [4]         0.012414
# winered      [10]          40000  0.1     False           [1]         0.005013
#                                                           [2]         0.005490
#                                                           [3]         0.005023
#                                                           [4]         0.005451
#                                                           [5]         0.005190

# %%
doubly = pd.read_csv("doubly.csv")
doubly = doubly.groupby(["dataset", "layers"]).agg(["mean", std]).drop("split", axis = 1)
doubly
# Out:
#                       NLL                RMSE                CRPS
#                      mean       std      mean       std      mean       std
# dataset  layers
# boston   1       2.621324  0.061539  3.461930  0.172243  1.778254  0.054756
#          2       2.619427  0.060715  3.464310  0.174090  1.775397  0.055053
#          3       2.618580  0.057986  3.477714  0.176407  1.780114  0.056023
#          4       2.612612  0.056778  3.459250  0.180476  1.768086  0.057338
#          5       2.619665  0.058376  3.483772  0.184585  1.778915  0.059403
# concrete 1       3.134538  0.016871  5.699006  0.128251  3.104325  0.057626
#          2       3.137992  0.016458  5.709117  0.127669  3.113382  0.057095
#          3       3.142599  0.016832  5.724927  0.129163  3.125693  0.058891
#          4       3.134859  0.017792  5.658314  0.130668  3.083788  0.057433
#          5       3.092611  0.015842  5.374571  0.115534  2.942421  0.051177
# energy   1       1.141213  0.016797  0.713296  0.020260  0.414601  0.009610
#          2       0.661802  0.019321  0.451084  0.012712  0.252025  0.005593
#          3       0.711009  0.021007  0.462688  0.013160  0.262231  0.005888
#          4       0.759983  0.021207  0.478973  0.014059  0.273281  0.006523
#          5       0.700959  0.021684  0.458096  0.015404  0.259230  0.007059
# naval    1      -6.475724  0.117892  0.000285  0.000035  0.000185  0.000020
#          2      -6.894672  0.101289  0.000152  0.000036  0.000119  0.000017
#          3      -7.025671  0.056709  0.000084  0.000014  0.000092  0.000007
# power    1       2.806324  0.009995  3.993163  0.040720  2.173505  0.011311
#          2       2.770222  0.009873  3.850422  0.038183  2.075122  0.009159
#          3       2.747370  0.012654  3.760601  0.049078  2.023911  0.015586
#          4       2.732378  0.011725  3.702821  0.045233  1.984471  0.012649
#          5       2.735273  0.010918  3.712386  0.041823  1.991525  0.009105
# protein  1       2.907479  0.002265  4.428554  0.011083  2.481267  0.005884
#          2       2.786240  0.002311  3.936413  0.010322  2.161253  0.004967
#          3       2.715014  0.002847  3.708458  0.011970  2.002001  0.005932
#          4       2.689973  0.002877  3.641484  0.011498  1.950791  0.005703
#          5       2.692614  0.004289  3.663181  0.016545  1.957200  0.008180
# wine_red 1       0.928739  0.012829  0.614669  0.008504  0.340628  0.004178
#          2       0.928976  0.012711  0.614753  0.008461  0.340674  0.004151
#          3       0.929331  0.012509  0.615001  0.008325  0.340852  0.004091
#          4       0.929474  0.012561  0.614968  0.008397  0.340988  0.004120
#          5       0.929893  0.012395  0.615139  0.008317  0.341113  0.004076

# %%
def comparative_plot(model_names, mean_values, std_values, colors, ax):
    """
    Creates a plot where the different models are shown in the "y" axis and mean and std values on the x axis.
    The first model is used to create a vertical dashed line, as a benchmark.
    """
    mean = np.nanmean(mean_values)
    std = np.nanstd(mean_values)
    nan_pos = np.isnan(mean_values)
    c = np.array(colors)
    c[nan_pos] = "white"
    means = np.array(mean_values)
    means[nan_pos] = mean
    
    far = means - mean > 2*std
    means[far] = mean
    c[far] = "white"
    ax.scatter(means, model_names, c = c, plotnonfinite = True)
    ax.hlines(np.array(model_names)[~far], np.array(mean_values - std_values)[~far],np.array(means + std_values)[~far], colors= np.array(colors)[~far])
    ax.axvline(mean_values[0], linestyle = "dashed", color = "k")
    x_min, x_max = ax.get_xlim()
    if far.any() != 0:
        slope = (x_max - x_min)/5
        ax.arrow(x = x_max - slope, y = np.array(model_names)[far][0], 
                 dx = slope, dy =0, color = np.array(colors)[far][0],
                 width = 0.002, head_width=0.3, head_length=slope/3, linewidth=1, length_includes_head = True,
                )
def get_dataset(dataset, metric, agg):
    if dataset == "winered":
        d_dataset = "wine_red"
    else:
        d_dataset = dataset
    vip_query = vip.query("dataset_name == @dataset").xs((metric, agg),axis=1).to_frame()
    vip100_query = vip100.query("dataset_name == @dataset").xs((metric, agg),axis=1).to_frame()
    doubly_query = doubly.query("dataset == @d_dataset").xs((metric, agg),axis=1).to_frame()
    
    def item(array):
        if array.size == 0:
            return np.nan
        else:
            return array.item()
    
    ret = {"VIP": item(vip_query.query("vip_layers == '[1]'").to_numpy()),
          "DVIP 2": item(vip_query.query("vip_layers == '[2]'").to_numpy()),
          "DVIP 3": item(vip_query.query("vip_layers == '[3]'").to_numpy()),
          "DVIP 4": item(vip_query.query("vip_layers == '[4]'").to_numpy()),
          "DVIP 5": item(vip_query.query("vip_layers == '[5]'").to_numpy()),
          "VIP 100": item(vip100_query.query("vip_layers == '[1]'").to_numpy()),
          "DGP": item(doubly_query.query("layers == 1").to_numpy()),
          "DGP 2": item(doubly_query.query("layers == 2").to_numpy()),
          "DGP 3": item(doubly_query.query("layers == 3").to_numpy()) or np.nan,
          "DGP 4": item(doubly_query.query("layers == 4").to_numpy()) or np.nan,
          "DGP 5": item(doubly_query.query("layers == 5").to_numpy()) or np.nan
    }
    
    return ret

def plot_datasets(dataset_names, model_names, colors, metric):
    fig, ax = plt.subplots((len(dataset_names) - 1)//4 + 1, min(len(dataset_names), 4), figsize = (20, 10))
    fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

    for i in range(len(dataset_names)):
        dataset = dataset_names[i]
        if len(dataset_names) < 4:
            axis = ax[i]
        else:
            axis = ax[i// (len(dataset_names)//2), i%(len(dataset_names)//2)]
        axis.set_title(dataset.capitalize())
        axis.locator_params(axis="x", nbins=4)
        if i % 4 > 0:
            axis.tick_params(left = False)
            axis.set_yticklabels([])
        if i % 4 == min(len(dataset_names), 4) - 1:
            axis.yaxis.tick_right()
            axis.set_yticklabels(model_names)
        
        
        comparative_plot(model_names, 
                         np.array([get_dataset(dataset, metric, "mean").get(model, np.nan) for model in model_names]), 
                         np.array([get_dataset(dataset, metric, "std").get(model, np.nan) for model in model_names]), 
                         [colors[model] for model in model_names], 
                         axis)
        
    handles = [
        Circle.Patch(color='darkblue', label='Single layer models'),
        Circle.Patch(color='teal', label='This work'),
        Circle.Patch(color='darkorange', label='Deep GP models'),
        Circle.Patch(color='orchid', label='Bayesian NN'),
    ]

    if len(dataset_names) < 4:
        ax[len(dataset_names) - 1].legend(loc='upper center', bbox_to_anchor=(-0.6, -0.05),
              fancybox=True, shadow=True, ncol=5, handles = handles)
    else:
        ax[1][1].legend(loc='upper center', bbox_to_anchor=(1.1, -0.15),
              fancybox=True, shadow=True, ncol=5, handles = handles)

# %%
dataset_names = ["boston", "energy", "concrete", "winered", "power", "naval", "protein", "kin8nm"]
model_names = ["VIP", "DVIP 2", "DVIP 3", "DVIP 4", "DVIP 5", "VIP 100", "DGP", "DGP 2", "DGP 3", "DGP 4", "DGP 5"]
colors = {"VIP": "darkblue", 
          "DVIP 2": "teal", 
          "DVIP 3": "teal", 
          "DVIP 4": "teal", 
          "DVIP 5": "teal", 
          "VIP 100": "darkblue", 
          "DGP": "darkblue",
          "DGP 2": "darkorange", 
          "DGP 3": "darkorange",
          "DGP 4": "darkorange",
          "DGP 5": "darkorange"}

# %%
plot_datasets(dataset_names, model_names, colors, "RMSE")

# %%
plot_datasets(dataset_names, model_names, colors, "NLL")

# %%
plot_datasets(dataset_names, model_names, colors, "CRPS")
