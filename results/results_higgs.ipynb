# %%
import os
import glob
import pandas as pd
os.chdir(".")

# %%
res = [i for i in glob.glob('DVIP_HIGGS/*')]
df = []
for f in res:
    try: 
        df.append(pd.read_csv(f))
    except:
        continue
df = pd.concat(df)
df = df.loc[:, (df != df.iloc[0]).any()] 
df = df.drop(["name_flag", "dataset", "activation", "bnn_layer", "final_layer_noise"], axis=1)
df.drop_duplicates(inplace = True)
df.to_csv("DVIP_Airline.csv", index = False)

# %%
res2 = [i for i in glob.glob('DGP_HIGGS/*')]
df2 = pd.concat([pd.read_csv(f) for f in res2 ]).drop(["Unnamed: 0"], axis = 1)
df2.to_csv("DGP_HIGGS.csv", index = False)

# %% [markdown]
# # DVIP

# %%
df.query("iterations == 500000 and bnn_layer_str == 'SimplerBayesLinear'")
# Out:
#    epochs  iterations vip_layers bnn_structure       bnn_layer_str  \
# 0       5      500000       [10]      [10, 10]  SimplerBayesLinear
# 0       5      500000        [1]      [10, 10]  SimplerBayesLinear
# 0       5      500000        [2]      [10, 10]  SimplerBayesLinear
# 0       5      500000        [3]      [10, 10]  SimplerBayesLinear
# 0       5      500000        [4]      [10, 10]  SimplerBayesLinear
# 0       5      500000        [5]      [10, 10]  SimplerBayesLinear
# 0       5      500000        [6]      [10, 10]  SimplerBayesLinear
# 0       5      500000        [7]      [10, 10]  SimplerBayesLinear
# 0       5      500000        [8]      [10, 10]  SimplerBayesLinear
# 0       5      500000        [9]      [10, 10]  SimplerBayesLinear
#
#            time          LOSS       NLL     Error       AUC  LOSS_train  \
# 0  38638.965308  22110.017578  0.525375  0.266991  0.814727         NaN
# 0   5187.356526   6646.283203  0.654733  0.392091  0.650852         NaN
# ...

# %% [markdown]
# # DGP

# %%
df2.query("iterations == 500000")
# Out:
#    split  layers  iterations  batch dataset       NLL       ACC       AUC  \
# 0      0       1      500000    100   HIGGS  0.574354  0.699416  0.769358
# 0      0       2      500000    100   HIGGS  0.514857  0.741382  0.822158
# 0      0       3      500000    100   HIGGS  0.501558  0.749090  0.831642
# 0      0       4      500000    100   HIGGS  0.500201  0.749550  0.832706
# 0      0       5      500000    100   HIGGS  0.500468  0.749136  0.832414
#
#             time
# 0    9032.536319
# 0   97662.861601
# 0  158177.109260
# 0  116014.482484
# 0  149608.184536
