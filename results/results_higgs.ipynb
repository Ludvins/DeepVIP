# %%
import os
import glob
import pandas as pd
os.chdir(".")

# %%
res = [i for i in glob.glob('DVIP_HIGGS/*')]
df = []
for f in res:
    try: 
        df.append(pd.read_csv(f))
    except:
        continue
df = pd.concat(df)
df = df.loc[:, (df != df.iloc[0]).any()] 
df = df.drop(["name_flag", "dataset", "activation", "final_layer_noise"], axis=1)
df.drop_duplicates(inplace = True)
df["ACC"] = 1 - df["Error"]
df.to_csv("DVIP_HIGGS.csv", index = False)

# %%
res2 = [i for i in glob.glob('DGP_HIGGS/*')]
df2 = pd.concat([pd.read_csv(f) for f in res2 ]).drop(["Unnamed: 0"], axis = 1)
df2.to_csv("DGP_HIGGS.csv", index = False)

# %% [markdown]
# # DVIP

# %%
df
# Out:
#   vip_layers          time          LOSS       NLL     Error       AUC  \
# 0        [1]   3580.046778   6851.365234  0.671543  0.425376  0.624785
# 0        [2]  12850.677215   8868.220703  0.614331  0.338974  0.719653
# 0        [3]  18537.185443  11430.539062  0.573184  0.301328  0.770428
# 0        [4]  24100.331971  13353.282227  0.567035  0.295707  0.778249
# 0        [5]  30118.264751  15601.369141  0.545350  0.279788  0.796257
#
#         ACC
# 0  0.574624
# 0  0.661026
# 0  0.698672
# 0  0.704293
# 0  0.720212

# %% [markdown]
# # DGP

# %%
df2
# Out:
#    split  layers  iterations  batch dataset       NLL       ACC       AUC  \
# 0      0       1      500000    100   HIGGS  0.574354  0.699416  0.769358
# 0      0       2      500000    100   HIGGS  0.514857  0.741382  0.822158
# 0      0       3      500000    100   HIGGS  0.501558  0.749090  0.831642
# 0      0       4      500000    100   HIGGS  0.500201  0.749550  0.832706
# 0      0       5      500000    100   HIGGS  0.500468  0.749136  0.832414
#
#             time
# 0    9032.536319
# 0   97662.861601
# 0  158177.109260
# 0  116014.482484
# 0  149608.184536
