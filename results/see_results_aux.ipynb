# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as Circle

import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Load CSV and drop columns where all the values coincide. For example, the activation used.

# %%
df = pd.read_csv("dvip_test.csv")
df = df.loc[:, (df != df.iloc[0]).any()]

# %% [markdown]
# Group table by their common parameters and compute mean and std over split

# %%
def std(x):
    return np.std(x)/np.sqrt(len(x))
full_df = df.groupby(["dataset_name", "epochs", "dropout", "vip_layers", "fix_prior_noise", "prior_kl", "zero_mean_prior", "bnn_structure"]).agg(["mean", std])
full_df
# Out:
#                                                                                               split  \
#                                                                                                mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]        9.5
#                                                                                 [10]            9.5
#                             [2]        True            False    False           [10, 10]        9.5
#                                                                                 [10]            9.5
#                             [3]        True            False    False           [10, 10]        9.5
# ...                                                                                             ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]        9.5
#                             [4]        True            False    False           [10]            9.5
#                                                                 True            [10, 10]        9.5
#                             [5]        True            False    False           [10]            9.5
#                                                                 True            [10, 10]        9.5
#
#                                                                                                         \
#                                                                                                    std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       1.28938
#                                                                                 [10]           1.28938
#                             [2]        True            False    False           [10, 10]       1.28938
#                                                                                 [10]           1.28938
#                             [3]        True            False    False           [10, 10]       1.28938
# ...                                                                                                ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       1.28938
#                             [4]        True            False    False           [10]           1.28938
#                                                                 True            [10, 10]       1.28938
#                             [5]        True            False    False           [10]           1.28938
#                                                                 True            [10, 10]       1.28938
#
#                                                                                                 LOSS_train  \
#                                                                                                       mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]        110.412336
#                                                                                 [10]             92.391862
#                             [2]        True            False    False           [10, 10]        137.308258
#                                                                                 [10]            119.731411
#                             [3]        True            False    False           [10, 10]        166.658802
# ...                                                                                                    ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       1645.940417
#                             [4]        True            False    False           [10]           1527.434656
#                                                                 True            [10, 10]       1659.936804
#                             [5]        True            False    False           [10]           1565.611090
#                                                                 True            [10, 10]       1670.517883
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       2.683153
#                                                                                 [10]           2.499132
#                             [2]        True            False    False           [10, 10]       2.538433
#                                                                                 [10]           2.684704
#                             [3]        True            False    False           [10, 10]       2.404505
# ...                                                                                                 ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       1.787668
#                             [4]        True            False    False           [10]           3.541869
#                                                                 True            [10, 10]       2.339174
#                             [5]        True            False    False           [10]           3.521059
#                                                                 True            [10, 10]       1.884622
#
#                                                                                               RMSE_train  \
#                                                                                                     mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]        1.718580
#                                                                                 [10]            1.873367
#                             [2]        True            False    False           [10, 10]        1.710933
#                                                                                 [10]            1.622232
#                             [3]        True            False    False           [10, 10]        1.983479
# ...                                                                                                  ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]        0.550658
#                             [4]        True            False    False           [10]            0.504037
#                                                                 True            [10, 10]        0.559811
#                             [5]        True            False    False           [10]            0.527948
#                                                                 True            [10, 10]        0.568867
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       0.011289
#                                                                                 [10]           0.012211
#                             [2]        True            False    False           [10, 10]       0.010802
#                                                                                 [10]           0.015877
#                             [3]        True            False    False           [10, 10]       0.016662
# ...                                                                                                 ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       0.001173
#                             [4]        True            False    False           [10]           0.002931
#                                                                 True            [10, 10]       0.001486
#                             [5]        True            False    False           [10]           0.002266
#                                                                 True            [10, 10]       0.001177
#
#                                                                                               NLL_train  \
#                                                                                                    mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       2.210671
#                                                                                 [10]           2.187915
#                             [2]        True            False    False           [10, 10]       2.173039
#                                                                                 [10]           2.101703
#                             [3]        True            False    False           [10, 10]       2.282110
# ...                                                                                                 ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       0.835685
#                             [4]        True            False    False           [10]           0.752034
#                                                                 True            [10, 10]       0.851993
#                             [5]        True            False    False           [10]           0.795692
#                                                                 True            [10, 10]       0.867288
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       0.006175
#                                                                                 [10]           0.005279
#                             [2]        True            False    False           [10, 10]       0.005000
#                                                                                 [10]           0.005676
#                             [3]        True            False    False           [10, 10]       0.006134
# ...                                                                                                 ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       0.001909
#                             [4]        True            False    False           [10]           0.005442
#                                                                 True            [10, 10]       0.002429
#                             [5]        True            False    False           [10]           0.004043
#                                                                 True            [10, 10]       0.001959
#
#                                                                                               CRPS_train  \
#                                                                                                     mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]        1.061091
#                                                                                 [10]            1.086267
#                             [2]        True            False    False           [10, 10]        1.046889
#                                                                                 [10]            0.981827
#                             [3]        True            False    False           [10, 10]        1.186677
# ...                                                                                                  ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]        0.306564
#                             [4]        True            False    False           [10]            0.279439
#                                                                 True            [10, 10]        0.310899
#                             [5]        True            False    False           [10]            0.291861
#                                                                 True            [10, 10]        0.315508
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       0.006214
#                                                                                 [10]           0.006194
#                             [2]        True            False    False           [10, 10]       0.005660
#                                                                                 [10]           0.006653
#                             [3]        True            False    False           [10, 10]       0.008136
# ...                                                                                                 ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       0.000643
#                             [4]        True            False    False           [10]           0.001488
#                                                                 True            [10, 10]       0.000779
#                             [5]        True            False    False           [10]           0.001331
#                                                                 True            [10, 10]       0.000639
#
#                                                                                                       LOSS  \
#                                                                                                       mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]        498.080840
#                                                                                 [10]            522.784389
#                             [2]        True            False    False           [10, 10]        691.616007
#                                                                                 [10]            710.401006
#                             [3]        True            False    False           [10, 10]        617.945708
# ...                                                                                                    ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       1814.159943
#                             [4]        True            False    False           [10]           1884.371722
#                                                                 True            [10, 10]       1811.655530
#                             [5]        True            False    False           [10]           1842.325726
#                                                                 True            [10, 10]       1812.231110
#
#                                                                                                           \
#                                                                                                      std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       53.380933
#                                                                                 [10]           38.561522
#                             [2]        True            False    False           [10, 10]       88.908197
#                                                                                 [10]           98.111273
#                             [3]        True            False    False           [10, 10]       71.362191
# ...                                                                                                  ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       19.992184
#                             [4]        True            False    False           [10]           36.139101
#                                                                 True            [10, 10]       23.868680
#                             [5]        True            False    False           [10]           33.394602
#                                                                 True            [10, 10]       22.382955
#
#                                                                                                    RMSE  \
#                                                                                                    mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       3.618699
#                                                                                 [10]           3.776935
#                             [2]        True            False    False           [10, 10]       3.817502
#                                                                                 [10]           3.747351
#                             [3]        True            False    False           [10, 10]       3.965386
# ...                                                                                                 ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       0.616804
#                             [4]        True            False    False           [10]           0.628136
#                                                                 True            [10, 10]       0.620206
#                             [5]        True            False    False           [10]           0.627813
#                                                                 True            [10, 10]       0.625488
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       0.173705
#                                                                                 [10]           0.123440
#                             [2]        True            False    False           [10, 10]       0.268718
#                                                                                 [10]           0.281456
#                             [3]        True            False    False           [10, 10]       0.265411
# ...                                                                                                 ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       0.007605
#                             [4]        True            False    False           [10]           0.010346
#                                                                 True            [10, 10]       0.009137
#                             [5]        True            False    False           [10]           0.010160
#                                                                 True            [10, 10]       0.008327
#
#                                                                                                     NLL  \
#                                                                                                    mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       2.762633
#                                                                                 [10]           2.861975
#                             [2]        True            False    False           [10, 10]       2.860851
#                                                                                 [10]           2.966786
#                             [3]        True            False    False           [10, 10]       2.837275
# ...                                                                                                 ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       0.936213
#                             [4]        True            False    False           [10]           0.960792
#                                                                 True            [10, 10]       0.943086
#                             [5]        True            False    False           [10]           0.958968
#                                                                 True            [10, 10]       0.951653
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       0.081219
#                                                                                 [10]           0.060973
#                             [2]        True            False    False           [10, 10]       0.138599
#                                                                                 [10]           0.169200
#                             [3]        True            False    False           [10, 10]       0.110514
# ...                                                                                                 ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       0.012076
#                             [4]        True            False    False           [10]           0.020680
#                                                                 True            [10, 10]       0.014612
#                             [5]        True            False    False           [10]           0.019144
#                                                                 True            [10, 10]       0.013410
#
#                                                                                                    CRPS  \
#                                                                                                    mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       1.853287
#                                                                                 [10]           1.964884
#                             [2]        True            False    False           [10, 10]       1.786650
#                                                                                 [10]           1.740022
#                             [3]        True            False    False           [10, 10]       1.875057
# ...                                                                                                 ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       0.341312
#                             [4]        True            False    False           [10]           0.345049
#                                                                 True            [10, 10]       0.342754
#                             [5]        True            False    False           [10]           0.345873
#                                                                 True            [10, 10]       0.346029
#
#
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       20000  0.1     [1]        True            False    False           [10, 10]       0.056509
#                                                                                 [10]           0.056135
#                             [2]        True            False    False           [10, 10]       0.081622
#                                                                                 [10]           0.084394
#                             [3]        True            False    False           [10, 10]       0.083094
# ...                                                                                                 ...
# winered      40000  0.1     [3]        True            False    True            [10, 10]       0.003774
#                             [4]        True            False    False           [10]           0.005451
#                                                                 True            [10, 10]       0.004384
#                             [5]        True            False    False           [10]           0.005190
#                                                                 True            [10, 10]       0.004024
#
# [261 rows x 18 columns]

# %% [markdown]
# # Comparative with other models

# %%
vip100 =  full_df.query("zero_mean_prior == False and epochs == 40000 and bnn_structure == '[100, 100]' and dropout == 0.1")
vip100
# Out:
#                                                                                                   split  \
#                                                                                                    mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     9.500000
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     9.500000
# energy       40000  0.1     [1]        True            False    False           [100, 100]     9.500000
# naval        40000  0.1     [1]        True            False    False           [100, 100]     8.400000
# power        40000  0.1     [1]        True            False    False           [100, 100]     6.666667
# winered      40000  0.1     [1]        True            False    False           [100, 100]     9.500000
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     1.289380
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     1.289380
# energy       40000  0.1     [1]        True            False    False           [100, 100]     1.289380
# naval        40000  0.1     [1]        True            False    False           [100, 100]     3.447898
# power        40000  0.1     [1]        True            False    False           [100, 100]     0.981307
# winered      40000  0.1     [1]        True            False    False           [100, 100]     1.289380
#
#                                                                                                  LOSS_train  \
#                                                                                                        mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]      -403.090915
# concrete     40000  0.1     [1]        True            False    False           [100, 100]      -523.686046
# energy       40000  0.1     [1]        True            False    False           [100, 100]     -1189.965643
# naval        40000  0.1     [1]        True            False    False           [100, 100]    -12866.564062
# power        40000  0.1     [1]        True            False    False           [100, 100]     -1419.721029
# winered      40000  0.1     [1]        True            False    False           [100, 100]       187.243884
#
#                                                                                                           \
#                                                                                                      std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]      2.266139
# concrete     40000  0.1     [1]        True            False    False           [100, 100]      8.572548
# energy       40000  0.1     [1]        True            False    False           [100, 100]      1.751701
# naval        40000  0.1     [1]        True            False    False           [100, 100]     17.624524
# power        40000  0.1     [1]        True            False    False           [100, 100]     20.784891
# winered      40000  0.1     [1]        True            False    False           [100, 100]      2.268114
#
#                                                                                               RMSE_train  \
#                                                                                                     mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]      0.267696
# concrete     40000  0.1     [1]        True            False    False           [100, 100]      1.458049
# energy       40000  0.1     [1]        True            False    False           [100, 100]      0.117665
# naval        40000  0.1     [1]        True            False    False           [100, 100]      0.000334
# power        40000  0.1     [1]        True            False    False           [100, 100]      3.249027
# winered      40000  0.1     [1]        True            False    False           [100, 100]      0.090865
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     0.003312
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     0.028968
# energy       40000  0.1     [1]        True            False    False           [100, 100]     0.001290
# naval        40000  0.1     [1]        True            False    False           [100, 100]     0.000004
# power        40000  0.1     [1]        True            False    False           [100, 100]     0.009481
# winered      40000  0.1     [1]        True            False    False           [100, 100]     0.000343
#
#                                                                                               NLL_train  \
#                                                                                                    mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     1.058159
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     2.055470
# energy       40000  0.1     [1]        True            False    False           [100, 100]     0.311845
# naval        40000  0.1     [1]        True            False    False           [100, 100]    -5.582504
# power        40000  0.1     [1]        True            False    False           [100, 100]     2.612527
# winered      40000  0.1     [1]        True            False    False           [100, 100]    -0.278957
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     0.004506
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     0.010434
# energy       40000  0.1     [1]        True            False    False           [100, 100]     0.002434
# naval        40000  0.1     [1]        True            False    False           [100, 100]     0.002659
# power        40000  0.1     [1]        True            False    False           [100, 100]     0.002800
# winered      40000  0.1     [1]        True            False    False           [100, 100]     0.001909
#
#                                                                                               CRPS_train  \
#                                                                                                     mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]      0.285299
# concrete     40000  0.1     [1]        True            False    False           [100, 100]      0.840855
# energy       40000  0.1     [1]        True            False    False           [100, 100]      0.134532
# naval        40000  0.1     [1]        True            False    False           [100, 100]      0.000371
# power        40000  0.1     [1]        True            False    False           [100, 100]      1.755334
# winered      40000  0.1     [1]        True            False    False           [100, 100]      0.078045
#
#                                                                                                              \
#                                                                                                         std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     1.425383e-03
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     7.972744e-03
# energy       40000  0.1     [1]        True            False    False           [100, 100]     4.162599e-04
# naval        40000  0.1     [1]        True            False    False           [100, 100]     6.102968e-07
# power        40000  0.1     [1]        True            False    False           [100, 100]     3.978214e-03
# winered      40000  0.1     [1]        True            False    False           [100, 100]     1.707176e-04
#
#                                                                                                        LOSS  \
#                                                                                                        mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]      3685.116028
# concrete     40000  0.1     [1]        True            False    False           [100, 100]       837.572041
# energy       40000  0.1     [1]        True            False    False           [100, 100]      -813.152246
# naval        40000  0.1     [1]        True            False    False           [100, 100]    -12799.758398
# power        40000  0.1     [1]        True            False    False           [100, 100]      -590.885061
# winered      40000  0.1     [1]        True            False    False           [100, 100]      5387.365955
#
#                                                                                                            \
#                                                                                                       std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     493.835913
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     153.898680
# energy       40000  0.1     [1]        True            False    False           [100, 100]      25.989766
# naval        40000  0.1     [1]        True            False    False           [100, 100]       7.512435
# power        40000  0.1     [1]        True            False    False           [100, 100]     174.101466
# winered      40000  0.1     [1]        True            False    False           [100, 100]     171.410034
#
#                                                                                                    RMSE  \
#                                                                                                    mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     3.348571
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     3.877127
# energy       40000  0.1     [1]        True            False    False           [100, 100]     0.414635
# naval        40000  0.1     [1]        True            False    False           [100, 100]     0.000352
# power        40000  0.1     [1]        True            False    False           [100, 100]     3.584339
# winered      40000  0.1     [1]        True            False    False           [100, 100]     0.578020
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     0.171408
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     0.130888
# energy       40000  0.1     [1]        True            False    False           [100, 100]     0.012840
# naval        40000  0.1     [1]        True            False    False           [100, 100]     0.000007
# power        40000  0.1     [1]        True            False    False           [100, 100]     0.065615
# winered      40000  0.1     [1]        True            False    False           [100, 100]     0.008863
#
#                                                                                                     NLL  \
#                                                                                                    mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     6.736981
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     3.025553
# energy       40000  0.1     [1]        True            False    False           [100, 100]     0.594359
# naval        40000  0.1     [1]        True            False    False           [100, 100]    -5.579109
# power        40000  0.1     [1]        True            False    False           [100, 100]     2.698216
# winered      40000  0.1     [1]        True            False    False           [100, 100]     1.836591
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     0.871211
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     0.109934
# energy       40000  0.1     [1]        True            False    False           [100, 100]     0.020212
# naval        40000  0.1     [1]        True            False    False           [100, 100]     0.002378
# power        40000  0.1     [1]        True            False    False           [100, 100]     0.017949
# winered      40000  0.1     [1]        True            False    False           [100, 100]     0.078158
#
#                                                                                                    CRPS  \
#                                                                                                    mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     1.761263
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     1.949076
# energy       40000  0.1     [1]        True            False    False           [100, 100]     0.230616
# naval        40000  0.1     [1]        True            False    False           [100, 100]     0.000375
# power        40000  0.1     [1]        True            False    False           [100, 100]     1.939639
# winered      40000  0.1     [1]        True            False    False           [100, 100]     0.313622
#
#
#                                                                                                         std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [100, 100]     5.635845e-02
# concrete     40000  0.1     [1]        True            False    False           [100, 100]     4.966855e-02
# energy       40000  0.1     [1]        True            False    False           [100, 100]     5.264395e-03
# naval        40000  0.1     [1]        True            False    False           [100, 100]     4.283174e-07
# power        40000  0.1     [1]        True            False    False           [100, 100]     1.178979e-02
# winered      40000  0.1     [1]        True            False    False           [100, 100]     4.819761e-03

# %%
vip = full_df.query("bnn_structure == '[10]' and epochs == 40000 and dropout == 0.1")
vip
# Out:
#                                                                                                    split  \
#                                                                                                     mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]            9.500000
#                             [2]        True            False    False           [10]            9.500000
#                             [3]        True            False    False           [10]            9.500000
#                             [4]        True            False    False           [10]            9.500000
#                             [5]        True            False    False           [10]            9.500000
# concrete     40000  0.1     [1]        True            False    False           [10]            9.500000
#                             [2]        True            False    False           [10]            9.500000
#                             [3]        True            False    False           [10]            9.500000
#                             [4]        True            False    False           [10]            9.500000
#                             [5]        True            False    False           [10]            9.500000
# energy       40000  0.1     [1]        True            False    False           [10]            9.500000
#                             [2]        True            False    False           [10]            9.500000
#                             [3]        True            False    False           [10]            9.500000
#                             [4]        True            False    False           [10]            9.500000
#                             [5]        True            False    False           [10]            9.500000
# kin8nm       40000  0.1     [1]        True            False    False           [10]            9.500000
#                             [2]        True            False    False           [10]           10.400000
#                             [3]        True            False    False           [10]            9.500000
#                             [4]        True            False    False           [10]            9.500000
#                             [5]        True            False    False           [10]            9.789474
# naval        40000  0.1     [1]        True            False    False           [10]            9.500000
#                             [2]        True            False    False           [10]            9.333333
#                             [3]        True            False    False           [10]            9.000000
#                             [4]        True            False    False           [10]           10.250000
#                             [5]        True            False    False           [10]            9.333333
# power        40000  0.1     [1]        True            False    False           [10]            9.157895
#                             [2]        True            False    False           [10]            9.500000
#                             [3]        True            False    False           [10]            9.500000
#                             [4]        True            False    False           [10]            9.500000
#                             [5]        True            False    False           [10]            9.473684
# protein      40000  0.1     [1]        True            False    False           [10]            9.500000
#                             [2]        True            False    False           [10]            9.500000
#                             [3]        True            False    False           [10]            8.400000
#                             [4]        True            False    False           [10]            9.076923
#                             [5]        True            False    False           [10]            9.333333
# winered      40000  0.1     [1]        True            False    False           [10]            9.500000
#                             [2]        True            False    False           [10]            9.500000
#                             [3]        True            False    False           [10]            9.500000
#                             [4]        True            False    False           [10]            9.500000
#                             [5]        True            False    False           [10]            9.500000
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]           1.289380
#                             [2]        True            False    False           [10]           1.289380
#                             [3]        True            False    False           [10]           1.289380
#                             [4]        True            False    False           [10]           1.289380
#                             [5]        True            False    False           [10]           1.289380
# concrete     40000  0.1     [1]        True            False    False           [10]           1.289380
#                             [2]        True            False    False           [10]           1.289380
#                             [3]        True            False    False           [10]           1.289380
#                             [4]        True            False    False           [10]           1.289380
#                             [5]        True            False    False           [10]           1.289380
# energy       40000  0.1     [1]        True            False    False           [10]           1.289380
#                             [2]        True            False    False           [10]           1.289380
#                             [3]        True            False    False           [10]           1.289380
#                             [4]        True            False    False           [10]           1.289380
#                             [5]        True            False    False           [10]           1.289380
# kin8nm       40000  0.1     [1]        True            False    False           [10]           1.289380
#                             [2]        True            False    False           [10]           1.602221
#                             [3]        True            False    False           [10]           1.289380
#                             [4]        True            False    False           [10]           1.289380
#                             [5]        True            False    False           [10]           1.324349
# naval        40000  0.1     [1]        True            False    False           [10]           1.289380
#                             [2]        True            False    False           [10]           1.672434
#                             [3]        True            False    False           [10]           2.398979
#                             [4]        True            False    False           [10]           1.366451
#                             [5]        True            False    False           [10]           2.621139
# power        40000  0.1     [1]        True            False    False           [10]           1.311072
#                             [2]        True            False    False           [10]           1.289380
#                             [3]        True            False    False           [10]           1.289380
#                             [4]        True            False    False           [10]           1.289380
#                             [5]        True            False    False           [10]           1.356973
# protein      40000  0.1     [1]        True            False    False           [10]           1.289380
#                             [2]        True            False    False           [10]           1.289380
#                             [3]        True            False    False           [10]           1.510850
#                             [4]        True            False    False           [10]           1.731919
#                             [5]        True            False    False           [10]           3.067150
# winered      40000  0.1     [1]        True            False    False           [10]           1.289380
#                             [2]        True            False    False           [10]           1.289380
#                             [3]        True            False    False           [10]           1.289380
#                             [4]        True            False    False           [10]           1.289380
#                             [5]        True            False    False           [10]           1.289380
#
#                                                                                                  LOSS_train  \
#                                                                                                        mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]              53.797577
#                             [2]        True            False    False           [10]              23.233875
#                             [3]        True            False    False           [10]              29.542371
#                             [4]        True            False    False           [10]              46.689050
#                             [5]        True            False    False           [10]              56.297681
# concrete     40000  0.1     [1]        True            False    False           [10]             225.211063
#                             [2]        True            False    False           [10]             174.208115
#                             [3]        True            False    False           [10]             210.333752
#                             [4]        True            False    False           [10]             196.101602
#                             [5]        True            False    False           [10]             206.085490
# energy       40000  0.1     [1]        True            False    False           [10]            -613.234775
#                             [2]        True            False    False           [10]            -628.050024
#                             [3]        True            False    False           [10]            -623.507385
#                             [4]        True            False    False           [10]            -655.976083
#                             [5]        True            False    False           [10]            -645.572046
# kin8nm       40000  0.1     [1]        True            False    False           [10]            3441.948230
#                             [2]        True            False    False           [10]            2495.811979
#                             [3]        True            False    False           [10]            2494.956494
#                             [4]        True            False    False           [10]            2535.011230
#                             [5]        True            False    False           [10]            2591.809609
# naval        40000  0.1     [1]        True            False    False           [10]           -6457.542261
#                             [2]        True            False    False           [10]           -6006.230892
#                             [3]        True            False    False           [10]           -6591.175084
#                             [4]        True            False    False           [10]           -7004.738586
#                             [5]        True            False    False           [10]           -6259.817627
# power        40000  0.1     [1]        True            False    False           [10]             -81.496474
#                             [2]        True            False    False           [10]            -182.460423
#                             [3]        True            False    False           [10]             -97.312710
#                             [4]        True            False    False           [10]            -123.590434
#                             [5]        True            False    False           [10]             -68.595976
# protein      40000  0.1     [1]        True            False    False           [10]           46645.436719
#                             [2]        True            False    False           [10]           44154.941211
#                             [3]        True            False    False           [10]           43752.765625
#                             [4]        True            False    False           [10]           43449.007212
#                             [5]        True            False    False           [10]           43496.608073
# winered      40000  0.1     [1]        True            False    False           [10]            1476.515869
#                             [2]        True            False    False           [10]            1477.869684
#                             [3]        True            False    False           [10]            1498.940063
#                             [4]        True            False    False           [10]            1527.434656
#                             [5]        True            False    False           [10]            1565.611090
#
#                                                                                                            \
#                                                                                                       std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]             3.072720
#                             [2]        True            False    False           [10]             3.437610
#                             [3]        True            False    False           [10]             2.576582
#                             [4]        True            False    False           [10]             2.289852
#                             [5]        True            False    False           [10]             3.636696
# concrete     40000  0.1     [1]        True            False    False           [10]             5.126468
#                             [2]        True            False    False           [10]             6.262989
#                             [3]        True            False    False           [10]             4.356289
#                             [4]        True            False    False           [10]             5.516550
#                             [5]        True            False    False           [10]             5.717979
# energy       40000  0.1     [1]        True            False    False           [10]             8.694284
#                             [2]        True            False    False           [10]             6.201846
#                             [3]        True            False    False           [10]             5.026115
#                             [4]        True            False    False           [10]             5.896202
#                             [5]        True            False    False           [10]             7.817825
# kin8nm       40000  0.1     [1]        True            False    False           [10]            33.414807
#                             [2]        True            False    False           [10]            35.698192
#                             [3]        True            False    False           [10]            23.495171
#                             [4]        True            False    False           [10]            31.743461
#                             [5]        True            False    False           [10]            24.425889
# naval        40000  0.1     [1]        True            False    False           [10]           140.102945
#                             [2]        True            False    False           [10]           128.649549
#                             [3]        True            False    False           [10]            92.200956
#                             [4]        True            False    False           [10]           212.078591
#                             [5]        True            False    False           [10]           130.556724
# power        40000  0.1     [1]        True            False    False           [10]            13.756106
#                             [2]        True            False    False           [10]            10.715474
#                             [3]        True            False    False           [10]            12.492144
#                             [4]        True            False    False           [10]            15.974090
#                             [5]        True            False    False           [10]            16.211555
# protein      40000  0.1     [1]        True            False    False           [10]            42.192498
#                             [2]        True            False    False           [10]            32.449119
#                             [3]        True            False    False           [10]            53.085940
#                             [4]        True            False    False           [10]            63.114616
#                             [5]        True            False    False           [10]           192.866690
# winered      40000  0.1     [1]        True            False    False           [10]             3.320617
#                             [2]        True            False    False           [10]             4.300125
#                             [3]        True            False    False           [10]             5.811296
#                             [4]        True            False    False           [10]             3.541869
#                             [5]        True            False    False           [10]             3.521059
#
#                                                                                               RMSE_train  \
#                                                                                                     mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]            1.630174
#                             [2]        True            False    False           [10]            1.284908
#                             [3]        True            False    False           [10]            1.371120
#                             [4]        True            False    False           [10]            1.449973
#                             [5]        True            False    False           [10]            1.535296
# concrete     40000  0.1     [1]        True            False    False           [10]            4.149938
#                             [2]        True            False    False           [10]            3.131192
#                             [3]        True            False    False           [10]            3.444831
#                             [4]        True            False    False           [10]            3.431895
#                             [5]        True            False    False           [10]            3.453342
# energy       40000  0.1     [1]        True            False    False           [10]            0.481016
#                             [2]        True            False    False           [10]            0.449728
#                             [3]        True            False    False           [10]            0.456140
#                             [4]        True            False    False           [10]            0.451377
#                             [5]        True            False    False           [10]            0.456288
# kin8nm       40000  0.1     [1]        True            False    False           [10]            0.091024
#                             [2]        True            False    False           [10]            0.071715
#                             [3]        True            False    False           [10]            0.069518
#                             [4]        True            False    False           [10]            0.069100
#                             [5]        True            False    False           [10]            0.069714
# naval        40000  0.1     [1]        True            False    False           [10]            0.000886
#                             [2]        True            False    False           [10]            0.000732
#                             [3]        True            False    False           [10]            0.000731
#                             [4]        True            False    False           [10]            0.000697
#                             [5]        True            False    False           [10]            0.000776
# power        40000  0.1     [1]        True            False    False           [10]            3.946804
#                             [2]        True            False    False           [10]            3.780622
#                             [3]        True            False    False           [10]            3.778856
#                             [4]        True            False    False           [10]            3.778304
#                             [5]        True            False    False           [10]            3.774702
# protein      40000  0.1     [1]        True            False    False           [10]            4.475468
#                             [2]        True            False    False           [10]            4.110850
#                             [3]        True            False    False           [10]            4.014822
#                             [4]        True            False    False           [10]            3.963348
#                             [5]        True            False    False           [10]            3.971132
# winered      40000  0.1     [1]        True            False    False           [10]            0.489995
#                             [2]        True            False    False           [10]            0.441884
#                             [3]        True            False    False           [10]            0.475937
#                             [4]        True            False    False           [10]            0.504037
#                             [5]        True            False    False           [10]            0.527948
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]           0.013515
#                             [2]        True            False    False           [10]           0.012121
#                             [3]        True            False    False           [10]           0.015094
#                             [4]        True            False    False           [10]           0.013127
#                             [5]        True            False    False           [10]           0.014940
# concrete     40000  0.1     [1]        True            False    False           [10]           0.030764
#                             [2]        True            False    False           [10]           0.029053
#                             [3]        True            False    False           [10]           0.032173
#                             [4]        True            False    False           [10]           0.025103
#                             [5]        True            False    False           [10]           0.023424
# energy       40000  0.1     [1]        True            False    False           [10]           0.003935
#                             [2]        True            False    False           [10]           0.002976
#                             [3]        True            False    False           [10]           0.002430
#                             [4]        True            False    False           [10]           0.002944
#                             [5]        True            False    False           [10]           0.002920
# kin8nm       40000  0.1     [1]        True            False    False           [10]           0.000379
#                             [2]        True            False    False           [10]           0.000319
#                             [3]        True            False    False           [10]           0.000232
#                             [4]        True            False    False           [10]           0.000325
#                             [5]        True            False    False           [10]           0.000251
# naval        40000  0.1     [1]        True            False    False           [10]           0.000014
#                             [2]        True            False    False           [10]           0.000008
#                             [3]        True            False    False           [10]           0.000016
#                             [4]        True            False    False           [10]           0.000018
#                             [5]        True            False    False           [10]           0.000016
# power        40000  0.1     [1]        True            False    False           [10]           0.005293
#                             [2]        True            False    False           [10]           0.005413
#                             [3]        True            False    False           [10]           0.006084
#                             [4]        True            False    False           [10]           0.006024
#                             [5]        True            False    False           [10]           0.006050
# protein      40000  0.1     [1]        True            False    False           [10]           0.004545
#                             [2]        True            False    False           [10]           0.003344
#                             [3]        True            False    False           [10]           0.007243
#                             [4]        True            False    False           [10]           0.006815
#                             [5]        True            False    False           [10]           0.029148
# winered      40000  0.1     [1]        True            False    False           [10]           0.001617
#                             [2]        True            False    False           [10]           0.002335
#                             [3]        True            False    False           [10]           0.003096
#                             [4]        True            False    False           [10]           0.002931
#                             [5]        True            False    False           [10]           0.002266
#
#                                                                                               NLL_train  \
#                                                                                                    mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]           2.092652
#                             [2]        True            False    False           [10]           1.886988
#                             [3]        True            False    False           [10]           1.935337
#                             [4]        True            False    False           [10]           1.979578
#                             [5]        True            False    False           [10]           2.019795
# concrete     40000  0.1     [1]        True            False    False           [10]           2.907127
#                             [2]        True            False    False           [10]           2.696251
#                             [3]        True            False    False           [10]           2.767373
#                             [4]        True            False    False           [10]           2.762923
#                             [5]        True            False    False           [10]           2.776058
# energy       40000  0.1     [1]        True            False    False           [10]           1.188351
#                             [2]        True            False    False           [10]           1.035639
#                             [3]        True            False    False           [10]           1.021011
#                             [4]        True            False    False           [10]           0.998029
#                             [5]        True            False    False           [10]           1.012029
# kin8nm       40000  0.1     [1]        True            False    False           [10]          -0.948688
#                             [2]        True            False    False           [10]          -1.146208
#                             [3]        True            False    False           [10]          -1.172744
#                             [4]        True            False    False           [10]          -1.171647
#                             [5]        True            False    False           [10]          -1.161799
# naval        40000  0.1     [1]        True            False    False           [10]          -4.986415
#                             [2]        True            False    False           [10]          -5.032643
#                             [3]        True            False    False           [10]          -5.080966
#                             [4]        True            False    False           [10]          -5.127719
#                             [5]        True            False    False           [10]          -5.048247
# power        40000  0.1     [1]        True            False    False           [10]           2.794305
#                             [2]        True            False    False           [10]           2.755554
#                             [3]        True            False    False           [10]           2.757780
#                             [4]        True            False    False           [10]           2.756272
#                             [5]        True            False    False           [10]           2.756482
# protein      40000  0.1     [1]        True            False    False           [10]           2.919321
#                             [2]        True            False    False           [10]           2.828759
#                             [3]        True            False    False           [10]           2.797458
#                             [4]        True            False    False           [10]           2.782138
#                             [5]        True            False    False           [10]           2.782843
# winered      40000  0.1     [1]        True            False    False           [10]           0.722847
#                             [2]        True            False    False           [10]           0.638522
#                             [3]        True            False    False           [10]           0.699697
#                             [4]        True            False    False           [10]           0.752034
#                             [5]        True            False    False           [10]           0.795692
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]           0.006916
#                             [2]        True            False    False           [10]           0.007282
#                             [3]        True            False    False           [10]           0.007238
#                             [4]        True            False    False           [10]           0.005628
#                             [5]        True            False    False           [10]           0.007266
# concrete     40000  0.1     [1]        True            False    False           [10]           0.006490
#                             [2]        True            False    False           [10]           0.007547
#                             [3]        True            False    False           [10]           0.006281
#                             [4]        True            False    False           [10]           0.005261
#                             [5]        True            False    False           [10]           0.005867
# energy       40000  0.1     [1]        True            False    False           [10]           0.011597
#                             [2]        True            False    False           [10]           0.008285
#                             [3]        True            False    False           [10]           0.006978
#                             [4]        True            False    False           [10]           0.008408
#                             [5]        True            False    False           [10]           0.008546
# kin8nm       40000  0.1     [1]        True            False    False           [10]           0.004208
#                             [2]        True            False    False           [10]           0.004704
#                             [3]        True            False    False           [10]           0.003196
#                             [4]        True            False    False           [10]           0.004893
#                             [5]        True            False    False           [10]           0.003197
# naval        40000  0.1     [1]        True            False    False           [10]           0.012996
#                             [2]        True            False    False           [10]           0.012358
#                             [3]        True            False    False           [10]           0.008050
#                             [4]        True            False    False           [10]           0.021667
#                             [5]        True            False    False           [10]           0.012944
# power        40000  0.1     [1]        True            False    False           [10]           0.001367
#                             [2]        True            False    False           [10]           0.001353
#                             [3]        True            False    False           [10]           0.001588
#                             [4]        True            False    False           [10]           0.001643
#                             [5]        True            False    False           [10]           0.001669
# protein      40000  0.1     [1]        True            False    False           [10]           0.001024
#                             [2]        True            False    False           [10]           0.000924
#                             [3]        True            False    False           [10]           0.001911
#                             [4]        True            False    False           [10]           0.001884
#                             [5]        True            False    False           [10]           0.007825
# winered      40000  0.1     [1]        True            False    False           [10]           0.002946
#                             [2]        True            False    False           [10]           0.004702
#                             [3]        True            False    False           [10]           0.005799
#                             [4]        True            False    False           [10]           0.005442
#                             [5]        True            False    False           [10]           0.004043
#
#                                                                                               CRPS_train  \
#                                                                                                     mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]            0.968748
#                             [2]        True            False    False           [10]            0.785733
#                             [3]        True            False    False           [10]            0.830805
#                             [4]        True            False    False           [10]            0.874740
#                             [5]        True            False    False           [10]            0.914133
# concrete     40000  0.1     [1]        True            False    False           [10]            2.360861
#                             [2]        True            False    False           [10]            1.822192
#                             [3]        True            False    False           [10]            1.987116
#                             [4]        True            False    False           [10]            1.983097
#                             [5]        True            False    False           [10]            2.003210
# energy       40000  0.1     [1]        True            False    False           [10]            0.355014
#                             [2]        True            False    False           [10]            0.311881
#                             [3]        True            False    False           [10]            0.309984
#                             [4]        True            False    False           [10]            0.304358
#                             [5]        True            False    False           [10]            0.308448
# kin8nm       40000  0.1     [1]        True            False    False           [10]            0.051099
#                             [2]        True            False    False           [10]            0.041159
#                             [3]        True            False    False           [10]            0.039986
#                             [4]        True            False    False           [10]            0.039856
#                             [5]        True            False    False           [10]            0.040235
# naval        40000  0.1     [1]        True            False    False           [10]            0.000719
#                             [2]        True            False    False           [10]            0.000667
#                             [3]        True            False    False           [10]            0.000642
#                             [4]        True            False    False           [10]            0.000613
#                             [5]        True            False    False           [10]            0.000667
# power        40000  0.1     [1]        True            False    False           [10]            2.156442
#                             [2]        True            False    False           [10]            2.060356
#                             [3]        True            False    False           [10]            2.063202
#                             [4]        True            False    False           [10]            2.061561
#                             [5]        True            False    False           [10]            2.061633
# protein      40000  0.1     [1]        True            False    False           [10]            2.512868
#                             [2]        True            False    False           [10]            2.270948
#                             [3]        True            False    False           [10]            2.203910
#                             [4]        True            False    False           [10]            2.168613
#                             [5]        True            False    False           [10]            2.171594
# winered      40000  0.1     [1]        True            False    False           [10]            0.273984
#                             [2]        True            False    False           [10]            0.247684
#                             [3]        True            False    False           [10]            0.265104
#                             [4]        True            False    False           [10]            0.279439
#                             [5]        True            False    False           [10]            0.291861
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]           0.006973
#                             [2]        True            False    False           [10]           0.005856
#                             [3]        True            False    False           [10]           0.006885
#                             [4]        True            False    False           [10]           0.005713
#                             [5]        True            False    False           [10]           0.007640
# concrete     40000  0.1     [1]        True            False    False           [10]           0.017171
#                             [2]        True            False    False           [10]           0.015417
#                             [3]        True            False    False           [10]           0.015431
#                             [4]        True            False    False           [10]           0.012733
#                             [5]        True            False    False           [10]           0.013200
# energy       40000  0.1     [1]        True            False    False           [10]           0.003703
#                             [2]        True            False    False           [10]           0.002335
#                             [3]        True            False    False           [10]           0.001781
#                             [4]        True            False    False           [10]           0.002329
#                             [5]        True            False    False           [10]           0.002343
# kin8nm       40000  0.1     [1]        True            False    False           [10]           0.000212
#                             [2]        True            False    False           [10]           0.000187
#                             [3]        True            False    False           [10]           0.000129
#                             [4]        True            False    False           [10]           0.000188
#                             [5]        True            False    False           [10]           0.000135
# naval        40000  0.1     [1]        True            False    False           [10]           0.000010
#                             [2]        True            False    False           [10]           0.000007
#                             [3]        True            False    False           [10]           0.000007
#                             [4]        True            False    False           [10]           0.000014
#                             [5]        True            False    False           [10]           0.000008
# power        40000  0.1     [1]        True            False    False           [10]           0.002138
#                             [2]        True            False    False           [10]           0.001910
#                             [3]        True            False    False           [10]           0.003211
#                             [4]        True            False    False           [10]           0.002422
#                             [5]        True            False    False           [10]           0.002503
# protein      40000  0.1     [1]        True            False    False           [10]           0.002876
#                             [2]        True            False    False           [10]           0.002282
#                             [3]        True            False    False           [10]           0.004507
#                             [4]        True            False    False           [10]           0.004868
#                             [5]        True            False    False           [10]           0.019764
# winered      40000  0.1     [1]        True            False    False           [10]           0.000877
#                             [2]        True            False    False           [10]           0.001257
#                             [3]        True            False    False           [10]           0.001595
#                             [4]        True            False    False           [10]           0.001488
#                             [5]        True            False    False           [10]           0.001331
#
#                                                                                                        LOSS  \
#                                                                                                        mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]             593.179288
#                             [2]        True            False    False           [10]            1015.400111
#                             [3]        True            False    False           [10]             937.961514
#                             [4]        True            False    False           [10]             805.041042
#                             [5]        True            False    False           [10]             794.341680
# concrete     40000  0.1     [1]        True            False    False           [10]             490.566457
#                             [2]        True            False    False           [10]             474.555566
#                             [3]        True            False    False           [10]             561.154958
#                             [4]        True            False    False           [10]             540.306839
#                             [5]        True            False    False           [10]             517.582629
# energy       40000  0.1     [1]        True            False    False           [10]            -584.378036
# ...
# naval        40000  0.1     [1]        True            False    False           [10]          -4.986141
#                             [2]        True            False    False           [10]          -5.031917
#                             [3]        True            False    False           [10]          -5.077460
#                             [4]        True            False    False           [10]          -5.123027
#                             [5]        True            False    False           [10]          -5.046939
# power        40000  0.1     [1]        True            False    False           [10]           2.813093
#                             [2]        True            False    False           [10]           2.781990
#                             [3]        True            False    False           [10]           2.783082
#                             [4]        True            False    False           [10]           2.781967
#                             [5]        True            False    False           [10]           2.781236
# protein      40000  0.1     [1]        True            False    False           [10]           2.928423
#                             [2]        True            False    False           [10]           2.847916
#                             [3]        True            False    False           [10]           2.817918
#                             [4]        True            False    False           [10]           2.805729
#                             [5]        True            False    False           [10]           2.811605
# winered      40000  0.1     [1]        True            False    False           [10]           0.994576
#                             [2]        True            False    False           [10]           0.956827
#                             [3]        True            False    False           [10]           0.950884
#                             [4]        True            False    False           [10]           0.960792
#                             [5]        True            False    False           [10]           0.958968
#
#                                                                                                          \
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]           0.066154
#                             [2]        True            False    False           [10]           0.259411
#                             [3]        True            False    False           [10]           0.224235
#                             [4]        True            False    False           [10]           0.209846
#                             [5]        True            False    False           [10]           0.210230
# concrete     40000  0.1     [1]        True            False    False           [10]           0.023991
#                             [2]        True            False    False           [10]           0.021733
#                             [3]        True            False    False           [10]           0.027105
#                             [4]        True            False    False           [10]           0.021874
#                             [5]        True            False    False           [10]           0.020716
# energy       40000  0.1     [1]        True            False    False           [10]           0.011341
#                             [2]        True            False    False           [10]           0.009983
#                             [3]        True            False    False           [10]           0.011430
#                             [4]        True            False    False           [10]           0.009258
#                             [5]        True            False    False           [10]           0.010389
# kin8nm       40000  0.1     [1]        True            False    False           [10]           0.006537
#                             [2]        True            False    False           [10]           0.007749
#                             [3]        True            False    False           [10]           0.005359
#                             [4]        True            False    False           [10]           0.006173
#                             [5]        True            False    False           [10]           0.003873
# naval        40000  0.1     [1]        True            False    False           [10]           0.013251
#                             [2]        True            False    False           [10]           0.012324
#                             [3]        True            False    False           [10]           0.007235
#                             [4]        True            False    False           [10]           0.021572
#                             [5]        True            False    False           [10]           0.012799
# power        40000  0.1     [1]        True            False    False           [10]           0.009966
#                             [2]        True            False    False           [10]           0.009310
#                             [3]        True            False    False           [10]           0.009286
#                             [4]        True            False    False           [10]           0.009216
#                             [5]        True            False    False           [10]           0.009916
# protein      40000  0.1     [1]        True            False    False           [10]           0.002879
#                             [2]        True            False    False           [10]           0.003013
#                             [3]        True            False    False           [10]           0.002584
#                             [4]        True            False    False           [10]           0.002747
#                             [5]        True            False    False           [10]           0.002265
# winered      40000  0.1     [1]        True            False    False           [10]           0.019848
#                             [2]        True            False    False           [10]           0.022689
#                             [3]        True            False    False           [10]           0.019352
#                             [4]        True            False    False           [10]           0.020680
#                             [5]        True            False    False           [10]           0.019144
#
#                                                                                                    CRPS  \
#                                                                                                    mean
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]           1.971254
#                             [2]        True            False    False           [10]           1.750940
#                             [3]        True            False    False           [10]           1.817736
#                             [4]        True            False    False           [10]           1.760835
#                             [5]        True            False    False           [10]           1.781601
# concrete     40000  0.1     [1]        True            False    False           [10]           2.999735
#                             [2]        True            False    False           [10]           2.393940
#                             [3]        True            False    False           [10]           2.719083
#                             [4]        True            False    False           [10]           2.679982
#                             [5]        True            False    False           [10]           2.655145
# energy       40000  0.1     [1]        True            False    False           [10]           0.374756
#                             [2]        True            False    False           [10]           0.323819
#                             [3]        True            False    False           [10]           0.320698
#                             [4]        True            False    False           [10]           0.316440
#                             [5]        True            False    False           [10]           0.321526
# kin8nm       40000  0.1     [1]        True            False    False           [10]           0.052749
#                             [2]        True            False    False           [10]           0.043652
#                             [3]        True            False    False           [10]           0.042982
#                             [4]        True            False    False           [10]           0.042634
#                             [5]        True            False    False           [10]           0.042817
# naval        40000  0.1     [1]        True            False    False           [10]           0.000720
#                             [2]        True            False    False           [10]           0.000668
#                             [3]        True            False    False           [10]           0.000647
#                             [4]        True            False    False           [10]           0.000618
#                             [5]        True            False    False           [10]           0.000668
# power        40000  0.1     [1]        True            False    False           [10]           2.188856
#                             [2]        True            False    False           [10]           2.109415
#                             [3]        True            False    False           [10]           2.111937
#                             [4]        True            False    False           [10]           2.109689
#                             [5]        True            False    False           [10]           2.107601
# protein      40000  0.1     [1]        True            False    False           [10]           2.534596
#                             [2]        True            False    False           [10]           2.315400
#                             [3]        True            False    False           [10]           2.251107
#                             [4]        True            False    False           [10]           2.223893
#                             [5]        True            False    False           [10]           2.238412
# winered      40000  0.1     [1]        True            False    False           [10]           0.353405
#                             [2]        True            False    False           [10]           0.338273
#                             [3]        True            False    False           [10]           0.339683
#                             [4]        True            False    False           [10]           0.345049
#                             [5]        True            False    False           [10]           0.345873
#
#
#                                                                                                     std
# dataset_name epochs dropout vip_layers fix_prior_noise prior_kl zero_mean_prior bnn_structure
# boston       40000  0.1     [1]        True            False    False           [10]           0.050567
#                             [2]        True            False    False           [10]           0.084163
#                             [3]        True            False    False           [10]           0.091140
#                             [4]        True            False    False           [10]           0.091951
#                             [5]        True            False    False           [10]           0.088049
# concrete     40000  0.1     [1]        True            False    False           [10]           0.051393
#                             [2]        True            False    False           [10]           0.047277
#                             [3]        True            False    False           [10]           0.067886
#                             [4]        True            False    False           [10]           0.056596
#                             [5]        True            False    False           [10]           0.057559
# energy       40000  0.1     [1]        True            False    False           [10]           0.004673
#                             [2]        True            False    False           [10]           0.004789
#                             [3]        True            False    False           [10]           0.005373
#                             [4]        True            False    False           [10]           0.003926
#                             [5]        True            False    False           [10]           0.004676
# kin8nm       40000  0.1     [1]        True            False    False           [10]           0.000414
#                             [2]        True            False    False           [10]           0.000391
#                             [3]        True            False    False           [10]           0.000292
#                             [4]        True            False    False           [10]           0.000311
#                             [5]        True            False    False           [10]           0.000232
# naval        40000  0.1     [1]        True            False    False           [10]           0.000010
#                             [2]        True            False    False           [10]           0.000008
#                             [3]        True            False    False           [10]           0.000006
#                             [4]        True            False    False           [10]           0.000014
#                             [5]        True            False    False           [10]           0.000009
# power        40000  0.1     [1]        True            False    False           [10]           0.012200
#                             [2]        True            False    False           [10]           0.009873
#                             [3]        True            False    False           [10]           0.010007
#                             [4]        True            False    False           [10]           0.010574
#                             [5]        True            False    False           [10]           0.011601
# protein      40000  0.1     [1]        True            False    False           [10]           0.007449
#                             [2]        True            False    False           [10]           0.007053
#                             [3]        True            False    False           [10]           0.006420
#                             [4]        True            False    False           [10]           0.006517
#                             [5]        True            False    False           [10]           0.007484
# winered      40000  0.1     [1]        True            False    False           [10]           0.005013
#                             [2]        True            False    False           [10]           0.005490
#                             [3]        True            False    False           [10]           0.005023
#                             [4]        True            False    False           [10]           0.005451
#                             [5]        True            False    False           [10]           0.005190

# %%
doubly = pd.read_csv("doubly.csv")
doubly.query("split == 0").groupby(["dataset", "layers"]).mean()
# Out:
#                  split       NLL      RMSE      CRPS
# dataset  layers
# boston   1           0  2.729527  3.863804  1.916543
#          2           0  2.728099  3.873859  1.916960
#          3           0  2.722751  3.872668  1.905442
#          4           0  2.721959  3.865386  1.886509
#          5           0  2.704314  3.854911  1.874212
# concrete 1           0  3.079898  5.233841  2.944245
#          2           0  3.093981  5.287726  2.979460
#          3           0  3.094287  5.294105  2.983695
#          4           0  3.056435  4.962057  2.832432
#          5           0  3.040199  4.915632  2.780979
# energy   1           0  1.080020  0.640521  0.379140
#          2           0  0.725272  0.495965  0.273172
#          3           0  0.830557  0.517736  0.297972
#          4           0  0.734630  0.495457  0.275241
#          5           0  0.722572  0.488744  0.272747
# kin8nm   1           0 -1.005328  0.081880  0.046887
#          2           0 -1.334087  0.063963  0.035804
#          3           0 -1.332997  0.064080  0.035836
# naval    1           0 -6.865809  0.000153  0.000113
#          2           0 -7.192096  0.000078  0.000076
#          3           0 -6.324822  0.000139  0.000175
#          4           0 -7.113030  0.000071  0.000080
# power    1           0  2.840120  4.134205  2.153474
#          2           0  2.825243  4.058459  2.081928
#          3           0  2.826552  4.071894  2.088785
#          4           0  2.791772  3.932153  1.982878
#          5           0  2.796132  3.938898  1.998841
# protein  1           0  2.898946  4.391515  2.457563
#          2           0  2.775983  3.892067  2.134421
#          3           0  2.715521  3.713039  2.004605
#          4           0  2.688797  3.635634  1.946585
# wine_red 1           0  0.940418  0.636108  0.340174
#          2           0  0.941127  0.637219  0.340773
#          3           0  0.935469  0.632815  0.338867
#          4           0  0.939706  0.634320  0.340213
#          5           0  0.944748  0.637068  0.341449

# %%
doubly = doubly.groupby(["dataset", "layers"]).agg(["mean", std]).drop("split", axis = 1)
doubly
# Out:
#                       NLL                RMSE                CRPS
#                      mean       std      mean       std      mean       std
# dataset  layers
# boston   1       2.621324  0.061539  3.461930  0.172243  1.778254  0.054756
#          2       2.619427  0.060715  3.464310  0.174090  1.775397  0.055053
#          3       2.618580  0.057986  3.477714  0.176407  1.780114  0.056023
#          4       2.612612  0.056778  3.459250  0.180476  1.768086  0.057338
#          5       2.619665  0.058376  3.483772  0.184585  1.778915  0.059403
# concrete 1       3.134538  0.016871  5.699006  0.128251  3.104325  0.057626
#          2       3.137992  0.016458  5.709117  0.127669  3.113382  0.057095
#          3       3.142599  0.016832  5.724927  0.129163  3.125693  0.058891
#          4       3.134859  0.017792  5.658314  0.130668  3.083788  0.057433
#          5       3.092611  0.015842  5.374571  0.115534  2.942421  0.051177
# energy   1       1.141213  0.016797  0.713296  0.020260  0.414601  0.009610
#          2       0.661802  0.019321  0.451084  0.012712  0.252025  0.005593
#          3       0.711009  0.021007  0.462688  0.013160  0.262231  0.005888
#          4       0.759983  0.021207  0.478973  0.014059  0.273281  0.006523
#          5       0.700959  0.021684  0.458096  0.015404  0.259230  0.007059
# kin8nm   1      -0.975375  0.003277  0.086898  0.000536  0.049229  0.000258
#          2      -1.350378  0.004308  0.062584  0.000347  0.035030  0.000162
#          3      -1.382660  0.006671  0.060735  0.000458  0.033985  0.000235
# naval    1      -6.475724  0.117892  0.000285  0.000035  0.000185  0.000020
#          2      -6.894672  0.101289  0.000152  0.000036  0.000119  0.000017
#          3      -7.039468  0.049660  0.000085  0.000012  0.000091  0.000006
#          4      -6.959729  0.055067  0.000109  0.000016  0.000102  0.000007
#          5      -6.873125  0.072354  0.000159  0.000025  0.000120  0.000010
# power    1       2.806324  0.009995  3.993163  0.040720  2.173505  0.011311
#          2       2.770222  0.009873  3.850422  0.038183  2.075122  0.009159
#          3       2.747370  0.012654  3.760601  0.049078  2.023911  0.015586
#          4       2.732378  0.011725  3.702821  0.045233  1.984471  0.012649
#          5       2.735273  0.010918  3.712386  0.041823  1.991525  0.009105
# protein  1       2.907479  0.002265  4.428554  0.011083  2.481267  0.005884
#          2       2.786240  0.002311  3.936413  0.010322  2.161253  0.004967
#          3       2.715014  0.002847  3.708458  0.011970  2.002001  0.005932
#          4       2.689973  0.002877  3.641484  0.011498  1.950791  0.005703
#          5       2.692614  0.004289  3.663181  0.016545  1.957200  0.008180
# wine_red 1       0.928739  0.012829  0.614669  0.008504  0.340628  0.004178
#          2       0.928976  0.012711  0.614753  0.008461  0.340674  0.004151
#          3       0.929331  0.012509  0.615001  0.008325  0.340852  0.004091
#          4       0.929474  0.012561  0.614968  0.008397  0.340988  0.004120
#          5       0.929893  0.012395  0.615139  0.008317  0.341113  0.004076

# %%
def comparative_plot(model_names, mean_values, std_values, colors, ax):
    """
    Creates a plot where the different models are shown in the "y" axis and mean and std values on the x axis.
    The first model is used to create a vertical dashed line, as a benchmark.
    """
    # Compute mean and std of points 
    mean = np.nanmean(mean_values)
    std = np.nanstd(mean_values)
    # Replace non-existint results (np.nan) with a white point (invisible).
    nan_pos = np.isnan(mean_values)
    c = np.array(colors)
    c[nan_pos] = "white"
    means = np.array(mean_values)
    means[nan_pos] = mean
    
    # Compute points that are far from the mean and meake them invisible
    far = means - mean > 2*std
    means[far] = mean
    c[far] = "white"
    
    # Scatter points
    ax.scatter(means, model_names, c = c, plotnonfinite = True)
    # Draw std horizontal lines
    ax.hlines(np.array(model_names)[~far], np.array(mean_values - std_values)[~far],np.array(means + std_values)[~far], colors= np.array(colors)[~far])
    # Draw baseline line on first model
    ax.axvline(mean_values[0], linestyle = "dashed", color = "k")
    
    # Plot an arrow for far points.
    if far.any() != 0:
        x_min, x_max = ax.get_xlim()
        slope = (x_max - x_min)/5
        ax.arrow(x = x_max - slope, y = np.array(model_names)[far][0], 
                 dx = slope, dy =0, color = np.array(colors)[far][0],
                 width = 0.002, head_width=0.3, head_length=slope/3, linewidth=1, length_includes_head = True,
                )
        
def get_dataset(dataset, metric, agg, train_metrics = False):
    if dataset == "winered":
        d_dataset = "wine_red"
    else:
        d_dataset = dataset
    vip_query = vip.query("dataset_name == @dataset").xs((metric + "_train" if train_metrics else metric, agg),axis=1).to_frame()
    #vip100_query = vip100.query("dataset_name == @dataset").xs((metric, agg),axis=1).to_frame()
    doubly_query = doubly.query("dataset == @d_dataset").xs((metric, agg),axis=1).to_frame()
    
    def item(array):
        if array.size == 0:
            return np.nan
        else:
            return array.item()
    
    ret = {"VIP": item(vip_query.query("vip_layers == '[1]'").to_numpy()),
          "DVIP 2": item(vip_query.query("vip_layers == '[2]'").to_numpy()),
          "DVIP 3": item(vip_query.query("vip_layers == '[3]'").to_numpy()),
          "DVIP 4": item(vip_query.query("vip_layers == '[4]'").to_numpy()),
          "DVIP 5": item(vip_query.query("vip_layers == '[5]'").to_numpy()),
          #"VIP 100": item(vip100_query.query("vip_layers == '[1]'").to_numpy()),
          "DGP": item(doubly_query.query("layers == 1").to_numpy()),
          "DGP 2": item(doubly_query.query("layers == 2").to_numpy()),
          "DGP 3": item(doubly_query.query("layers == 3").to_numpy()) or np.nan,
          "DGP 4": item(doubly_query.query("layers == 4").to_numpy()) or np.nan,
          "DGP 5": item(doubly_query.query("layers == 5").to_numpy()) or np.nan
    }
    
    return ret

def plot_datasets(dataset_names, model_names, colors, metric, train_metrics = False):
    fig, ax = plt.subplots((len(dataset_names) - 1)//4 + 1, min(len(dataset_names), 4), figsize = (20, 10))
    fig.tight_layout() # Or equivalently,  "plt.tight_layout()"

    for i in range(len(dataset_names)):
        dataset = dataset_names[i]
        if len(dataset_names) < 4:
            axis = ax[i]
        else:
            axis = ax[i// (len(dataset_names)//2), i%(len(dataset_names)//2)]
        axis.set_title(dataset.capitalize())
        axis.locator_params(axis="x", nbins=4)
        if i % 4 > 0:
            axis.tick_params(left = False)
            axis.set_yticklabels([])
        if i % 4 == min(len(dataset_names), 4) - 1:
            axis.yaxis.tick_right()
            axis.set_yticklabels(model_names)
        
        
        comparative_plot(model_names, 
                         np.array([get_dataset(dataset, metric, "mean", train_metrics).get(model, np.nan) for model in model_names]), 
                         np.array([get_dataset(dataset, metric, "std", train_metrics).get(model, np.nan) for model in model_names]), 
                         [colors[model] for model in model_names], 
                         axis)
        
    handles = [
        Circle.Patch(color='darkblue', label='Single layer models'),
        Circle.Patch(color='teal', label='This work'),
        Circle.Patch(color='darkorange', label='Deep GP models'),
        Circle.Patch(color='orchid', label='Bayesian NN'),
    ]

    if len(dataset_names) < 4:
        ax[len(dataset_names) - 1].legend(loc='upper center', bbox_to_anchor=(-0.6, -0.05),
              fancybox=True, shadow=True, ncol=5, handles = handles)
    else:
        ax[1][1].legend(loc='upper center', bbox_to_anchor=(1.1, -0.15),
              fancybox=True, shadow=True, ncol=5, handles = handles)

# %%
dataset_names = ["boston", "energy", "concrete", "winered", "power", "naval", "protein", "kin8nm"]
model_names = ["VIP", "DVIP 2", "DVIP 3", "DVIP 4", "DVIP 5", "VIP 100", "DGP", "DGP 2", "DGP 3", "DGP 4", "DGP 5"]
colors = {"VIP": "darkblue", 
          "DVIP 2": "teal", 
          "DVIP 3": "teal", 
          "DVIP 4": "teal", 
          "DVIP 5": "teal", 
          "VIP 100": "darkblue", 
          "DGP": "darkblue",
          "DGP 2": "darkorange", 
          "DGP 3": "darkorange",
          "DGP 4": "darkorange",
          "DGP 5": "darkorange"}

# %%
plot_datasets(dataset_names, model_names, colors, "RMSE")

# %%
plot_datasets(dataset_names, model_names, colors, "RMSE", train_metrics = True)

# %%
plot_datasets(dataset_names, model_names, colors, "NLL")

# %%
plot_datasets(dataset_names, model_names, colors, "NLL", train_metrics = True)

# %%
plot_datasets(dataset_names, model_names, colors, "CRPS")

# %%
plot_datasets(dataset_names, model_names, colors, "CRPS", train_metrics = True)
