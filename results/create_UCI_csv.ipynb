# %%
import os
import glob
import pandas as pd
os.chdir(".")

# %%
res1 = [i for i in glob.glob('DVIP_UCI/*')]
df = []
for f in res1:
    try: 
        df.append(pd.read_csv(f))
    except:
        continue
df = pd.concat(df)
df = df.loc[:, (df != df.iloc[0]).any()]

# %%
df = df.drop(["name_flag", "dataset", "bnn_layer", "epochs", "activation", "final_layer_noise"], axis=1)
df
# Out:
#    dataset_name vip_layers  bb_alpha bnn_structure  split       bnn_layer_str  \
# 0        boston        [1]       0.5      [10, 10]      0         BayesLinear
# 0        boston        [1]       0.5      [10, 10]      1         BayesLinear
# 0        boston        [1]       0.5      [10, 10]     10         BayesLinear
# 0        boston        [1]       0.5      [10, 10]     11         BayesLinear
# 0        boston        [1]       0.5      [10, 10]     12         BayesLinear
# ..          ...        ...       ...           ...    ...                 ...
# 0       winered        [5]       0.0      [10, 10]      5  SimplerBayesLinear
# 0       winered        [5]       0.0      [10, 10]      6  SimplerBayesLinear
# 0       winered        [5]       0.0      [10, 10]      7  SimplerBayesLinear
# 0       winered        [5]       0.0      [10, 10]      8  SimplerBayesLinear
# 0       winered        [5]       0.0      [10, 10]      9  SimplerBayesLinear
#
# ...

# %%
df.to_csv("DVIP_UCI.csv", index = False)
