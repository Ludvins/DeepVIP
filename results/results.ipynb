# %%
import os
import glob
import pandas as pd
os.chdir(".")

# %%
# Out:
# ['DVIP_UCI\\dataset=boston_vip-layers=1_epochs=30000_batch=100_genf=BNN_bnn-structure=10-10_act=tanh_regression-coeffs=20_alpha=0.5_prior-fixed-noise_split=0.csv', 'DVIP_UCI\\dataset=boston_vip-layers=1_epochs=30000_batch=100_genf=BNN_bnn-structure=10-10_act=tanh_regression-coeffs=20_alpha=0.5_prior-fixed-noise_split=1.csv', 'DVIP_UCI\\dataset=boston_vip-layers=1_epochs=30000_batch=100_genf=BNN_bnn-structure=10-10_act=tanh_regression-coeffs=20_alpha=0.5_prior-fixed-noise_split=10.csv', 'DVIP_UCI\\dataset=boston_vip-layers=1_epochs=30000_batch=100_genf=BNN_bnn-structure=10-10_act=tanh_regression-coeffs=20_alpha=0.5_prior-fixed-noise_split=11.csv', 'DVIP_UCI\\dataset=boston_vip-layers=1_epochs=30000_batch=100_genf=BNN_bnn-structure=10-10_act=tanh_regression-coeffs=20_alpha=0.5_prior-fixed-noise_split=12.csv', 'DVIP_UCI\\dataset=boston_vip-layers=1_epochs=30000_batch=100_genf=BNN_bnn-structure=10-10_act=tanh_regression-coeffs=20_alpha=0.5_prior-fixed-noise_split=13.csv', 'DVIP_UCI\\data
# ...

# %%
res1 = [i for i in glob.glob('DVIP_UCI/*')]
df = []
for f in res1:
    try: 
        df.append(pd.read_csv(f))
    except:
        continue
df = pd.concat(df)
df = df.loc[:, (df != df.iloc[0]).any()]

# %%
df = df.drop(["name_flag", "dataset", "activation", "final_layer_noise"], axis=1)

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#    dataset_name  epochs vip_layers  bb_alpha  split         time  LOSS_train  \
# 0        boston   30000        [1]       0.5      0   947.088792   83.050125
# 0        boston   30000        [1]       0.5      1  1771.547177   77.932961
# 0        boston   30000        [1]       0.5     10   720.077081   88.203262
# 0        boston   30000        [1]       0.5     11   724.710273   90.321083
# 0        boston   30000        [1]       0.5     12   737.149604   83.512566
# ..          ...     ...        ...       ...    ...          ...         ...
# 0       winered   10000        [5]       0.0      5  3285.199776  185.255463
# 0       winered   10000        [5]       0.0      6  3390.904119  170.520706
# 0       winered   10000        [5]       0.0      7  4145.718367  165.053528
# 0       winered   10000        [5]       0.0      8  3322.538187  181.589508
# 0       winered   10000        [5]       0.0      9  3334.048608  193.716888
#
# ...

# %%
df.to_csv("DVIP_UCI.csv", index = False)

# %%
res2 = [i for i in glob.glob('DGP_UCI/*')]

# %%
df2 = pd.concat([pd.read_csv(f) for f in res2 ]).drop(["Unnamed: 0"], axis = 1)

# %%
df2.to_csv("DGP_UCI.csv", index = False)
