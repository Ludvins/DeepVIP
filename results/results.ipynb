# %%
import os
import glob
import pandas as pd
os.chdir(".")

# %%
res = [i for i in glob.glob('DVIP_Year/*')]
df = []
for f in res:
    try: 
        df.append(pd.read_csv(f))
    except:
        continue
df = pd.concat(df)
df = df.loc[:, (df != df.iloc[0]).any()]

# %%
df = df.drop(["name_flag", "dataset", "activation", "bnn_layer", "final_layer_noise"], axis=1)

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#   vip_layers       bnn_layer_str          time   LOSS_train  RMSE_train  \
# 0        [1]         BayesLinear   1005.374782   209.540283    8.836220
# 0        [1]  SimplerBayesLinear   1989.354091   230.230850   10.303126
# 0        [2]         BayesLinear   2166.726589  1118.055298    8.811317
# 0        [2]  SimplerBayesLinear  11781.980509  2473.703613    9.711894
# 0        [3]         BayesLinear   3455.419034  1446.568115    8.921138
# 0        [3]  SimplerBayesLinear  10133.756521  4290.166016    9.251826
# 0        [4]         BayesLinear   4711.753453  1615.358887    8.901680
# 0        [4]  SimplerBayesLinear   4427.024702  4976.868652    9.167904
# 0        [5]         BayesLinear   6082.814767  1811.859985    8.945880
# 0        [5]  SimplerBayesLinear   5542.170348  5902.345215    9.074400
#
#    NLL_train  CRPS_train         LOSS       RMSE       NLL      CRPS
# 0   3.597800    4.666924   211.132736   8.978765  3.614020  4.744016
# 0   3.751390    5.554047   229.719589  10.254123  3.746630  5.536237
# 0   3.593076    4.649846  1119.438232   8.936359  3.607149  4.715931
# 0   3.692280    5.202965  2474.180420   9.760879  3.697211  5.227026
# 0   3.605818    4.699306  1447.450562   9.002665  3.614781  4.749621
# 0   3.642124    4.932489  4291.028809   9.335629  3.650739  4.976564
# 0   3.603075    4.701972  1616.439209   9.000197  3.614006  4.758894
# 0   3.632700    4.862086  4977.722656   9.250142  3.641315  4.912851
# 0   3.608516    4.726845  1812.712280   9.025681  3.617330  4.773818
# 0   3.620955    4.820838  5903.525879   9.186478  3.633076  4.883072

# %%
df.to_csv("DVIP_Year.csv", index = False)

# %%
res2 = [i for i in glob.glob('DGP_Year/*')]

# %%
df2 = pd.concat([pd.read_csv(f) for f in res2 ]).drop(["Unnamed: 0"], axis = 1)

# %%
df2.to_csv("DGP_Year.csv", index = False)
